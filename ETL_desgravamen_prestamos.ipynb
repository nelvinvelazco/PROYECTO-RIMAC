# %%
import pandas as pd
from datetime import datetime
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
import os
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_errores= pd.read_excel('c:/data/tabla_errores2.xlsx', sheet_name='Sheet1', dtype={'CODIGO_ERROR': str, 'IDEERROR': str})
df_errores.head(3)
# Out:
#   IDEERROR CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0     0974         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1     0005         0003                            ERROR EN CARGA DE TRAMA
# 2     1158         1155                         TRAMA REPETIDA O DUPLICADA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
# 2                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION_2
# 0  ANULAR MASIVAS
# 1             NaN
# 2  ANULAR MASIVAS

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IDEERROR           53 non-null     object
#  1   CODIGO_ERROR       53 non-null     object
#  2   DESCRIPCION_ERROR  54 non-null     object
#  3   DETALLE            54 non-null     object
#  4   SOLUCION           54 non-null     object
#  5   SOLUCION_2         19 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
#df_equivalencias= pd.read_excel('c:/data/Tabla_equivalencias.xlsx', sheet_name='Sheet1', dtype={'IDEERROR': str, 'CODERROR': str})
#df_equivalencias= df_equivalencias[['IDEERROR', 'CODERROR']]
#df_equivalencias.rename(columns={'CODERROR': 'CODIGO_ERROR'}, inplace=True)
#df_equivalencias.head(3)
# Out:
#   IDEERROR CODIGO_ERROR
# 0     0092         0050
# 1     0097         0114
# 2     0101         0117

# %%
#df_errores = df_errores.merge(df_equivalencias, on='CODIGO_ERROR', how='left')
#col = df_errores.pop("IDEERROR")          # Sacamos la columna
#df_errores.insert(0, "IDEERROR", col)     # La insertamos en la primera posición
#df_errores.head(2)
# Out:
#   IDEERROR CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0     0974         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1     0005         0003                            ERROR EN CARGA DE TRAMA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
#
#        SOLUCION_2
# 0  ANULAR MASIVAS
# 1             NaN

# %%
#df_errores.to_excel('c:/data/tabla_errores2.xlsx', index=False)

# %%
df_desgravamen= pd.read_csv('C:/data/Reporte de errores/RESULTADO SCRIPT ERRORES CONSUER.csv', 
                              dtype={'COD DE CERTIFICADO': str, 'DESCRIPCION ERROR': str, 'IDELOTE': str, 'CODIGO ERROR': str})

# %%
df_desgravamen= pd.read_csv('C:/data/data.csv')

# %%
df_desgravamen.to_excel('C:/data/data.xlsx', index=False)

# %%
df_desgravamen.head(3)
# Out:
#    NRO LOTE LOTES ANTERIORES             FECHA CARGA  CODIGO PRODUCTO  \
# 0    142173              NaN  01/08/2018 06:05:50 PM           5780.0
# 1    142173              NaN  01/08/2018 06:05:50 PM           5780.0
# 2    142173              NaN  01/08/2018 06:05:50 PM           5780.0
#
#                         PRODUCTO  CODIGO PLAN  \
# 0  BBVA Desgravamen Migracion CF     262176.0
# 1  BBVA Desgravamen Migracion CF     262176.0
# 2  BBVA Desgravamen Migracion CF     262176.0
#
#                                       NOMBRE DE PLAN    COD DE CERTIFICADO  \
# 0  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 1  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 2  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
#
#   fecini_alta_CERTIFICADO fecfin_alta_CERTIFICADO     IDEDET TIPO MOVIMIENTO  \
# 0              30/01/2018              30/06/2019  244557631      Renovacion
# 1              30/01/2018              30/06/2019  244557631      Renovacion
# 2              30/01/2018              30/06/2019  244557631      Renovacion
#
#   FEC. INICIO    FEC. FIN MONEDA  SUMA ASEGURADA  TASA  TASA RECARGO  \
# 0  31/03/2018  30/04/2018    USD             0.0   0.0           0.0
# 1  31/03/2018  30/04/2018    USD             0.0   0.0           0.0
# 2  31/03/2018  30/04/2018    USD             0.0   0.0           0.0
#
#    PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO APEMATERNO  \
# 0           9.45          9.17         NaN        NaN        NaN
# 1           9.45          9.17         NaN        NaN        NaN
# 2           9.45          9.17         NaN        NaN        NaN
#
#    FECNACIMIENTO  TIPDOCUMENTO  NUMDOCUMENTO  \
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
#
#                       NOMBRE DE ARCHIVO  \
# 0  20100130204_0169001_20180801_005.TXT
# 1  20100130204_0169001_20180801_005.TXT
# 2  20100130204_0169001_20180801_005.TXT
#
#                                          LINEA TRAMA IDELOTE   IDEDET.1  \
# 0  94100110151814000181932                    01U...  142173  244557631
# 1  94100110151814000181932                    01U...  142173  244557631
# 2  94100110151814000181932                    01U...  142173  244557631
#
#   ORIGEN ERROR CODIGO ERROR                                  DESCRIPCION ERROR
# 0  Error Rimac         1106  [**ERROR**]La suma para reasegurar es cero.[PO...
# 1  Error Rimac         1106  [**ERROR**]La suma para reasegurar es cero.[PO...
# 2  Error Rimac         1106  [**ERROR**]La suma para reasegurar es cero.[PO...

# %%
# Se carga el dataset en excel de Accidentes mortales
df_desgravamen= pd.read_excel('C:/data/Reporte de errores/446 - Desgravamen - 03.xlsx', sheet_name='Sheet1', 
                              dtype={'COD DE CERTIFICADO': str, 'DESCRIPCION ERROR': str, 'IDELOTE': str, 'CODIGO ERROR': str})

# %%
df_desgravamen.head(3)
# Out:
#    NRO LOTE LOTES ANTERIORES         FECHA CARGA  CODIGO PRODUCTO  \
# 0    872654              NaN 2022-10-25 17:52:43           3827.0
# 1    872654              NaN 2022-10-25 17:52:43           3827.0
# 2    872654              NaN 2022-10-25 17:52:43           3827.0
#
#                        PRODUCTO  CODIGO PLAN   NOMBRE DE PLAN  \
# 0  Desgravamen + Desempleo BBVA      89705.0  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA      89705.0  Plan Contifacil
# 2  Desgravamen + Desempleo BBVA      89705.0  Plan Contifacil
#
#      COD DE CERTIFICADO fecini_alta_CERTIFICADO fecfin_alta_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
# 2  00110814184000055299              2016-09-26              2020-09-28
#
#       IDEDET TIPO MOVIMIENTO FEC. INICIO    FEC. FIN MONEDA  SUMA ASEGURADA  \
# 0  556035505       Exclusion  30/12/2019  30/12/2022    SOL          2800.0
# 1  556035505       Exclusion  30/12/2019  30/12/2022    SOL          2800.0
# 2  556035940       Exclusion  26/09/2016  28/09/2020    SOL          6200.0
#
#    TASA  TASA RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 2  0.35          0.35           2.17          2.11  JAIRO LUIS        FEIJOO
#
#     APEMATERNO  FECNACIMIENTO  TIPDOCUMENTO NUMDOCUMENTO  \
# 0        MU?OZ     19880329.0           2.0     44994753
# 1        MU?OZ     19880329.0           2.0     44994753
# 2  DEL ROSARIO     19821102.0           2.0     41618166
#
#                       NOMBRE DE ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
# 2  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA TRAMA IDELOTE   IDEDET.1  \
# 0  901001108141740012031430011081410960091807101P...  872654  556035505
# 1  901001108141740012031430011081410960091807101P...  872654  556035505
# 2  901001108141840000552990011081416960004645701P...  872654  556035940
#
#   ORIGEN ERROR CODIGO ERROR                                  DESCRIPCION ERROR
# 0  Error canal          986  EL NUMERO DE CERTIFICADO [00110814174001203143...
# 1  Error canal         2025  EL CAMPO FECEXCLUSION DEL(A) CERTIFICADO DEBE ...
# 2  Error canal          843  EL CAMPO NRO CERTIFICADO CANAL/CORREDOR SE ENC...

# %%
df_desgravamen.columns = (
    df_desgravamen.columns
    .str.strip()  # quitar espacios al inicio/fin
    .str.upper()  # opcional: todo en mayúsculas
    .str.replace(r'[^A-Za-z0-9]', '_', regex=True)  # reemplazar todo lo que no sea letra/número/_ por _
)

# %%
df_desgravamen.drop(['IDELOTE','IDEDET_1','DESCRIPCION_ERROR'], axis=1, inplace=True)

# %%
df_desgravamen= df_desgravamen.rename(columns={'CODIGO_ERROR': 'IDEERROR'})

# %%
#df_desgravamen= df_desgravamen[['CODIGO_PRODUCTO', 'LOTES_ANTERIORES','COD_DE_CERTIFICADO', 'FECINI_ALTA_CERTIFICADO', 
 #                               'FECFIN_ALTA_CERTIFICADO','IDEDET', 'TRAMA', 'TIPO_MOVIMIENTO', 'FEC__INICIO', 
  #                              'FEC__FIN', 'MONEDA', 'SUMA_ASEGURADA', 'TASA', 'PRIMABRUTACAN', 'PRIMANETACAN', 
   #                             'NOMBRE_DE_ARCHIVO', 'ORIGEN_ERROR', 'TIPO_ERROR', 'CODIGO_ERROR']]

# %%
df_desgravamen[df_desgravamen['IDEERROR'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR]
# Index: []

# %%
df_desgravamen['MONEDA'].value_counts()
# Out:
# MONEDA
# SOL    7867
# USD     548
# Name: count, dtype: int64

# %%
#df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'SUMA_ASEGURADA':0, 'TASA':0, 'PRIMABRUTACAN':0, 'PRIMANETACAN':0,
 #                                      'MONEDA': 'SIN DATO'})

# %%
df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'MONEDA': 'SIN DATO', 'ORIGEN_ERROR': 'SIN DATO', 'TIPDOCUMENTO':'SIN DATO'})
df_desgravamen.loc[df_desgravamen['MONEDA'] == 'nan', 'MONEDA'] = 'SIN DATO'
df_desgravamen.loc[df_desgravamen['ORIGEN_ERROR'] == 'nan', 'ORIGEN_ERROR'] = 'SIN DATO'

# %%
def limpiar_fecha(columna):
    col = columna.astype(str) # Convertir a string
    col = col.str.strip()  # Eliminar espacios
    # Quitar decimales tipo '19880329.0'
    col = col.str.replace(r"\.0$", "", regex=True)
    col = col.str[:8] # Mantener solo los 8 primeros caracteres
    # Reemplazar valores inválidos (que no tengan 8 dígitos) por NaN
    col = col.where(col.str.match(r"^\d{8}$"), np.nan)
    return pd.to_datetime(col, format="%Y%m%d", errors="coerce")  # Convertir a fecha

# %%
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)
#df_desgravamen['FECHA_CARGA'] = pd.to_datetime(df_desgravamen['FECHA_CARGA'], errors='coerce')
df_desgravamen['FECHA_CARGA'] = pd.to_datetime(df_desgravamen['FECHA_CARGA'], format="%d/%m/%Y %I:%M:%S %p", errors='coerce')
df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["PRODUCTO"] = df_desgravamen["PRODUCTO"].astype(str)
df_desgravamen['CODIGO_PLAN'] = df_desgravamen['CODIGO_PLAN'].fillna(0).astype('int')
df_desgravamen["NOMBRE_DE_PLAN"] = df_desgravamen["NOMBRE_DE_PLAN"].astype(str)
df_desgravamen["COD_DE_CERTIFICADO"] = df_desgravamen["COD_DE_CERTIFICADO"].astype(str)
#df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
#df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen["TIPO_MOVIMIENTO"] = df_desgravamen["TIPO_MOVIMIENTO"].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['TASA_RECARGO'] = pd.to_numeric(df_desgravamen['TASA_RECARGO'], errors='coerce')
df_desgravamen['NOMCOMPLETO'] = df_desgravamen['NOMCOMPLETO'].astype(str)
df_desgravamen['APEPATERNO'] = df_desgravamen['APEPATERNO'].astype(str)
df_desgravamen['APEMATERNO'] = df_desgravamen['APEMATERNO'].astype(str)
df_desgravamen["FECNACIMIENTO"] = limpiar_fecha(df_desgravamen["FECNACIMIENTO"])
df_desgravamen["TIPDOCUMENTO"] = df_desgravamen["TIPDOCUMENTO"].astype(str)
df_desgravamen['NUMDOCUMENTO'] = df_desgravamen['NUMDOCUMENTO'].astype(str)
df_desgravamen['NOMBRE_DE_ARCHIVO'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].astype(str)
df_desgravamen['LINEA_TRAMA'] = df_desgravamen['LINEA_TRAMA'].astype(str)
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].astype(str)
df_desgravamen['IDEERROR'] = df_desgravamen['IDEERROR'].apply(lambda x: str(int(x)).zfill(4) if pd.notnull(x) else np.nan)

# %%
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FECHA_CARGA'] = pd.to_datetime(df_desgravamen['FECHA_CARGA'], format="%d/%m/%Y %I:%M:%S %p", errors='coerce')

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    142173                  2018-08-01 18:05:50             5780
# 1    142173                  2018-08-01 18:05:50             5780
# 2    142173                  2018-08-01 18:05:50             5780
#
#                         PRODUCTO  CODIGO_PLAN  \
# 0  BBVA Desgravamen Migracion CF       262176
# 1  BBVA Desgravamen Migracion CF       262176
# 2  BBVA Desgravamen Migracion CF       262176
#
#                                       NOMBRE_DE_PLAN    COD_DE_CERTIFICADO  \
# 0  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 1  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 2  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0              2018-01-30              2019-06-30  244557631      Renovacion
# 1              2018-01-30              2019-06-30  244557631      Renovacion
# 2              2018-01-30              2019-06-30  244557631      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  \
# 0  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 1  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 2  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
#
#    PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO APEMATERNO  \
# 0           9.45          9.17         nan        nan        nan
# 1           9.45          9.17         nan        nan        nan
# 2           9.45          9.17         nan        nan        nan
#
#   FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0           NaT     SIN DATO          nan
# 1           NaT     SIN DATO          nan
# 2           NaT     SIN DATO          nan
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0169001_20180801_005.TXT
# 1  20100130204_0169001_20180801_005.TXT
# 2  20100130204_0169001_20180801_005.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR IDEERROR
# 0  94100110151814000181932                    01U...  Error Rimac     1106
# 1  94100110151814000181932                    01U...  Error Rimac     1106
# 2  94100110151814000181932                    01U...  Error Rimac     1106

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8415 entries, 0 to 8414
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_LOTE                 8415 non-null   int64
#  1   LOTES_ANTERIORES         8415 non-null   object
#  2   FECHA_CARGA              8415 non-null   datetime64[ns]
#  3   CODIGO_PRODUCTO          8415 non-null   int64
#  4   PRODUCTO                 8415 non-null   object
#  5   CODIGO_PLAN              8415 non-null   int64
#  6   NOMBRE_DE_PLAN           8415 non-null   object
#  7   COD_DE_CERTIFICADO       8415 non-null   object
#  8   FECINI_ALTA_CERTIFICADO  8365 non-null   datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  8365 non-null   datetime64[ns]
#  10  IDEDET                   8415 non-null   int64
#  11  TIPO_MOVIMIENTO          8415 non-null   object
#  12  FEC__INICIO              8415 non-null   datetime64[ns]
#  13  FEC__FIN                 8413 non-null   datetime64[ns]
#  14  MONEDA                   8415 non-null   object
#  15  SUMA_ASEGURADA           8413 non-null   float64
#  16  TASA                     8415 non-null   float64
#  17  TASA_RECARGO             8415 non-null   float64
#  18  PRIMABRUTACAN            8413 non-null   float64
#  19  PRIMANETACAN             8415 non-null   float64
#  20  NOMCOMPLETO              8415 non-null   object
#  21  APEPATERNO               8415 non-null   object
#  22  APEMATERNO               8415 non-null   object
#  23  FECNACIMIENTO            11 non-null     datetime64[ns]
#  24  TIPDOCUMENTO             8415 non-null   object
#  25  NUMDOCUMENTO             8415 non-null   object
#  26  NOMBRE_DE_ARCHIVO        8415 non-null   object
#  27  LINEA_TRAMA              8415 non-null   object
#  28  ORIGEN_ERROR             8415 non-null   object
#  29  IDEERROR                 8415 non-null   object
# dtypes: datetime64[ns](6), float64(5), int64(4), object(15)
# memory usage: 1.9+ MB

# %%
df= df_desgravamen.copy()

# %%
df_desgravamen[df_desgravamen['LOTES_ANTERIORES']==""].head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    142173                  2018-08-01 18:05:50             5780
# 1    142173                  2018-08-01 18:05:50             5780
# 2    142173                  2018-08-01 18:05:50             5780
#
#                         PRODUCTO  CODIGO_PLAN  \
# 0  BBVA Desgravamen Migracion CF       262176
# 1  BBVA Desgravamen Migracion CF       262176
# 2  BBVA Desgravamen Migracion CF       262176
#
#                                       NOMBRE_DE_PLAN    COD_DE_CERTIFICADO  \
# 0  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 1  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 2  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0              2018-01-30              2019-06-30  244557631      Renovacion
# 1              2018-01-30              2019-06-30  244557631      Renovacion
# 2              2018-01-30              2019-06-30  244557631      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  \
# 0  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 1  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 2  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
#
#    PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO APEMATERNO  \
# 0           9.45          9.17         nan        nan        nan
# 1           9.45          9.17         nan        nan        nan
# 2           9.45          9.17         nan        nan        nan
#
#   FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0           NaT     SIN DATO          nan
# 1           NaT     SIN DATO          nan
# 2           NaT     SIN DATO          nan
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0169001_20180801_005.TXT
# 1  20100130204_0169001_20180801_005.TXT
# 2  20100130204_0169001_20180801_005.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR IDEERROR
# 0  94100110151814000181932                    01U...  Error Rimac     1106
# 1  94100110151814000181932                    01U...  Error Rimac     1106
# 2  94100110151814000181932                    01U...  Error Rimac     1106

# %%
df_desgravamen['ORIGEN_ERROR'].value_counts()
# Out:
# ORIGEN_ERROR
# Error Rimac    8089
# Error canal     326
# Name: count, dtype: int64

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    872654                  2022-10-25 17:52:43             3827
# 1    872654                  2022-10-25 17:52:43             3827
# 2    872654                  2022-10-25 17:52:43             3827
#
#                        PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN  \
# 0  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 2  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
#
#      COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
# 2  00110814184000055299              2016-09-26              2020-09-28
#
#       IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 0  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 1  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 2  556035940       Exclusion  2016-09-26 2020-09-28    SOL          6200.0
#
#    TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 2  0.35          0.35           2.17          2.11  JAIRO LUIS        FEIJOO
#
#     APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0        MU?OZ    1988-03-29          2.0     44994753
# 1        MU?OZ    1988-03-29          2.0     44994753
# 2  DEL ROSARIO    1982-11-02          2.0     41618166
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
# 2  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR IDEERROR
# 0  901001108141740012031430011081410960091807101P...  Error canal     0986
# 1  901001108141740012031430011081410960091807101P...  Error canal     2025
# 2  901001108141840000552990011081416960004645701P...  Error canal     0843

# %%
#df_desgravamen['COD_DE_CERTIFICADO'] = df_desgravamen['COD_DE_CERTIFICADO'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
"""df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)

df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['TIPO_MOVIMIENTO'] = df_desgravamen['TIPO_MOVIMIENTO'].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['SUMA_ASEGURADA']= pd.to_numeric(df_desgravamen['SUMA_ASEGURADA'], errors='coerce')
df_desgravamen['TASA']= pd.to_numeric(df_desgravamen['TASA'], errors='coerce')
df_desgravamen['PRIMABRUTACAN']= pd.to_numeric(df_desgravamen['PRIMABRUTACAN'], errors='coerce')
df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].fillna(0).astype('int')
"""
# Out:
# 'df_desgravamen[\'CODIGO_PRODUCTO\'] = df_desgravamen[\'CODIGO_PRODUCTO\'].fillna(0).astype(\'int\')\ndf_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)\n\ndf_desgravamen[\'FECINI_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECINI_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'TIPO_MOVIMIENTO\'] = df_desgravamen[\'TIPO_MOVIMIENTO\'].astype(str)\ndf_desgravamen[\'FEC__INICIO\'] = pd.to_datetime(df_desgravamen[\'FEC__INICIO\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'FEC__FIN\'] = pd.to_datetime(df_desgravamen[\'FEC__FIN\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'MONEDA\'] = df_desgravamen[\'MONEDA\'].astype(str)\ndf_desgravamen[\'SUMA_ASEGURADA\']= pd.to_numeric(df_desgravamen[\'SUMA_ASEGURADA\'], errors=\'coerce\')\ndf_desgravamen[\'TASA\']= pd.to_numeric(df_desgravamen[\'TASA\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMABRUTACAN\']= pd.to_numeric(df_desgravamen[\'PRIMABRUTACAN\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMANETACAN\']= pd.to_numeric(df_desgravamen[\'PRIMANETACAN\'], errors=\'coerce\')\ndf_desgravamen[\'ORIGEN_ERROR\'] = df_desgravamen[\'ORIGEN_ERROR\'].fillna(0).astype(\'int\')\n'

# %%
#TIPO MOVIMIENTO
df_desgravamen['FECINI_ALTA_CERTIFICADO'].value_counts()  # Counting occurrences of each unique value in the 'TIPO MOVIMIENTO' column
# Out:
# FECINI_ALTA_CERTIFICADO
# 2020-01-30    434
# 2020-02-07    292
# 2020-02-21    252
# 2020-02-06    212
# 2020-02-17    204
#              ...
# 2020-11-30      2
# 2021-10-29      2
# 2018-02-01      1
# 2018-02-13      1
# 2018-01-25      1
# Name: count, Length: 206, dtype: int64

# %%
df_desgravamen[df_desgravamen['FEC__INICIO'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR]
# Index: []

# %%
#MONEDA
df_desgravamen['MONEDA'].value_counts()  # Counting occurrences of each unique value in the 'MONEDA' column
# Out:
# MONEDA
# SOL    7867
# USD     548
# Name: count, dtype: int64

# %%
df_desgravamen['TIPO_MOVIMIENTO'].value_counts()
# Out:
# TIPO_MOVIMIENTO
# Renovacion        8403
# Sin Movimiento       7
# Inclusion            5
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['TIPO_MOVIMIENTO'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR]
# Index: []

# %%
df_desgravamen[df_desgravamen['MONEDA']=='SIN DATO'].head()
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR]
# Index: []

# %%
def extraer_fecha(fecha):
    try:
        fecha_str = fecha.split("_")[2]
        return datetime.strptime(fecha_str, "%Y%m%d").date()
    except Exception:
        return None  # En caso de error

# %%
# Aplicar a la columna
df_desgravamen['FECHA_TRAMA'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].apply(extraer_fecha)

# %%
df_desgravamen.head(2)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    142173                  2018-08-01 18:05:50             5780
# 1    142173                  2018-08-01 18:05:50             5780
#
#                         PRODUCTO  CODIGO_PLAN  \
# 0  BBVA Desgravamen Migracion CF       262176
# 1  BBVA Desgravamen Migracion CF       262176
#
#                                       NOMBRE_DE_PLAN    COD_DE_CERTIFICADO  \
# 0  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 1  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0              2018-01-30              2019-06-30  244557631      Renovacion
# 1              2018-01-30              2019-06-30  244557631      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  \
# 0  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 1  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
#
#    PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO APEMATERNO  \
# 0           9.45          9.17         nan        nan        nan
# 1           9.45          9.17         nan        nan        nan
#
#   FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0           NaT     SIN DATO          nan
# 1           NaT     SIN DATO          nan
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0169001_20180801_005.TXT
# 1  20100130204_0169001_20180801_005.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR IDEERROR  \
# 0  94100110151814000181932                    01U...  Error Rimac     1106
# 1  94100110151814000181932                    01U...  Error Rimac     1106
#
#   FECHA_TRAMA
# 0  2018-08-01
# 1  2018-08-01

# %%
df_desgravamen['FECHA_TRAMA'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8415 entries, 0 to 8414
# Series name: FECHA_TRAMA
# Non-Null Count  Dtype
# --------------  -----
# 8415 non-null   object
# dtypes: object(1)
# memory usage: 65.9+ KB

# %%
df_desgravamen['FECHA_TRAMA']= pd.to_datetime(df_desgravamen['FECHA_TRAMA'], errors='coerce')

# %%
def clasificar(row):
    # Si lote no esta vacio
    if str(row['LOTES_ANTERIORES']).strip() != "":
        return 'Regularizacion no Exitosa'
    
    # Si último número del nombre de archivo > 100
    try:
        ultimo_numero = int(row['NOMBRE_DE_ARCHIVO'].split("_")[-1][:-4])
        if ultimo_numero > 100:
            return 'Regularizacion no Exitosa'
    except:
        pass
    
    # Si ninguna condición se cumple
    return 'Mes corriente'

# %%
nombre = '20100130204_0157001_20150409_001_41924.TXT'
numero= int(nombre.split("_")[-1][:-4])
print(numero)
# Out:
# 41924

# %%
#df_desgravamen['REGULARIZACION']= df_desgravamen['LOTES ANTERIORES'].notnull()
df_desgravamen['STATUS']= df_desgravamen.apply(clasificar, axis=1)

# %%
df_desgravamen['STATUS'].value_counts()
# Out:
# STATUS
# Mes corriente                5255
# Regularizacion no Exitosa    3160
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['STATUS']=='Mes corriente'].head(2)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    142173                  2018-08-01 18:05:50             5780
# 1    142173                  2018-08-01 18:05:50             5780
#
#                         PRODUCTO  CODIGO_PLAN  \
# 0  BBVA Desgravamen Migracion CF       262176
# 1  BBVA Desgravamen Migracion CF       262176
#
#                                       NOMBRE_DE_PLAN    COD_DE_CERTIFICADO  \
# 0  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
# 1  Plan BBVA Desgravamen Vehiculos y Motos Migrac...  00110151814000181932
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0              2018-01-30              2019-06-30  244557631      Renovacion
# 1              2018-01-30              2019-06-30  244557631      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  \
# 0  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
# 1  2018-03-31 2018-04-30    USD             0.0   0.0           0.0
#
#    PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO APEMATERNO  \
# 0           9.45          9.17         nan        nan        nan
# 1           9.45          9.17         nan        nan        nan
#
#   FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0           NaT     SIN DATO          nan
# 1           NaT     SIN DATO          nan
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0169001_20180801_005.TXT
# 1  20100130204_0169001_20180801_005.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR IDEERROR  \
# 0  94100110151814000181932                    01U...  Error Rimac     1106
# 1  94100110151814000181932                    01U...  Error Rimac     1106
#
#   FECHA_TRAMA         STATUS
# 0  2018-08-01  Mes corriente
# 1  2018-08-01  Mes corriente

# %%
df_errores[df_errores['CODIGO_ERROR'].isna()].head(10)
# Out:
#    IDEERROR CODIGO_ERROR        DESCRIPCION_ERROR            DETALLE  \
# 12      NaN          NaN  ERROR EN CARGA DE TRAMA  NI ÉXITO NI ERROR
#
#            SOLUCION SOLUCION_2
# 12  ANALISIS EMISOR        NaN

# %%
df_errores[df_errores['CODIGO_ERROR'].isin({'2395','7440'})].head()
# Out:
#    IDEERROR CODIGO_ERROR DESCRIPCION_ERROR                       DETALLE  \
# 11     2048         2395     ERROR DE TASA                          TASA
# 37     1566         7440        ERROR EDAD  EDAD - MANCOMUNO INEXISTENTE
#
#              SOLUCION          SOLUCION_2
# 11    ANALISIS EMISOR   CONFIGURACION SAS
# 37  CONFIGURACION SAS  REGLAS POR CAMBIAR

# %%
df_errores[df_errores['CODIGO_ERROR']==' '].head()
# Out:
# Empty DataFrame
# Columns: [IDEERROR, CODIGO_ERROR, DESCRIPCION_ERROR, DETALLE, SOLUCION, SOLUCION_2]
# Index: []

# %%
df_desgravamen[df_desgravamen['IDEERROR'].isna()].head(10)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR, FECHA_TRAMA, STATUS]
# Index: []

# %%
df_desgravamen[df_desgravamen['IDEERROR']==''].head()
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, IDEERROR, FECHA_TRAMA, STATUS]
# Index: []

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IDEERROR           53 non-null     object
#  1   CODIGO_ERROR       53 non-null     object
#  2   DESCRIPCION_ERROR  54 non-null     object
#  3   DETALLE            54 non-null     object
#  4   SOLUCION           54 non-null     object
#  5   SOLUCION_2         19 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
df= df_desgravamen.merge(df_errores, on='IDEERROR', how='left')

# %%
df['DESCRIPCION_ERROR'].value_counts()
# Out:
# DESCRIPCION_ERROR
# VALIDACIONES CONSECUENCIA ACSEL E                             7836
# ERROR EN ALTA                                                  281
# ERROR EN CARGA DE TRAMA                                        229
# SIN POLIZA                                                       5
# TRAMA REPETIDA O DUPLICADA                                       5
# YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO DE VIGENCIA       2
# CAMPOS EN BLANCO                                                 1
# NI ÉXITO NI ERROR                                                1
# Name: count, dtype: int64

# %%
df['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 0177    115762
# 0130       853
# 0011       235
# 0022       233
# 0193       104
# 0117        91
# 0163        48
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8415 entries, 0 to 8414
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_LOTE                 8415 non-null   int64
#  1   LOTES_ANTERIORES         8415 non-null   object
#  2   FECHA_CARGA              8415 non-null   datetime64[ns]
#  3   CODIGO_PRODUCTO          8415 non-null   int64
#  4   PRODUCTO                 8415 non-null   object
#  5   CODIGO_PLAN              8415 non-null   int64
#  6   NOMBRE_DE_PLAN           8415 non-null   object
#  7   COD_DE_CERTIFICADO       8415 non-null   object
#  8   FECINI_ALTA_CERTIFICADO  8365 non-null   datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  8365 non-null   datetime64[ns]
#  10  IDEDET                   8415 non-null   int64
#  11  TIPO_MOVIMIENTO          8415 non-null   object
#  12  FEC__INICIO              8415 non-null   datetime64[ns]
#  13  FEC__FIN                 8413 non-null   datetime64[ns]
#  14  MONEDA                   8415 non-null   object
#  15  SUMA_ASEGURADA           8413 non-null   float64
#  16  TASA                     8415 non-null   float64
#  17  TASA_RECARGO             8415 non-null   float64
#  18  PRIMABRUTACAN            8413 non-null   float64
#  19  PRIMANETACAN             8415 non-null   float64
#  20  NOMCOMPLETO              8415 non-null   object
#  21  APEPATERNO               8415 non-null   object
#  22  APEMATERNO               8415 non-null   object
#  23  FECNACIMIENTO            11 non-null     datetime64[ns]
#  24  TIPDOCUMENTO             8415 non-null   object
#  25  NUMDOCUMENTO             8415 non-null   object
#  26  NOMBRE_DE_ARCHIVO        8415 non-null   object
#  27  LINEA_TRAMA              8415 non-null   object
#  28  ORIGEN_ERROR             8415 non-null   object
#  29  IDEERROR                 8415 non-null   object
#  30  FECHA_TRAMA              8415 non-null   datetime64[ns]
#  31  STATUS                   8415 non-null   object
#  32  CODIGO_ERROR             8360 non-null   object
#  33  DESCRIPCION_ERROR        8360 non-null   object
#  34  DETALLE                  8360 non-null   object
#  35  SOLUCION                 8360 non-null   object
#  36  SOLUCION_2               13 non-null     object
# dtypes: datetime64[ns](7), float64(5), int64(4), object(21)
# memory usage: 2.4+ MB
