# %%
import pandas as pd
from datetime import datetime
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
import os
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_errores= pd.read_excel('c:/data/tabla_errores.xlsx', sheet_name='Sheet1', dtype={'CODIGO_ERROR': str})
df_errores.head(3)
# Out:
#   CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1         0003                            ERROR EN CARGA DE TRAMA
# 2         1155                         TRAMA REPETIDA O DUPLICADA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
# 2                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION_2
# 0  ANULAR MASIVAS
# 1             NaN
# 2  ANULAR MASIVAS

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       52 non-null     object
#  1   DESCRIPCION_ERROR  53 non-null     object
#  2   DETALLE            53 non-null     object
#  3   SOLUCION           53 non-null     object
#  4   SOLUCION_2         19 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
#df_errores.to_excel('c:/data/tabla_errores.xlsx', index=False)

# %%
# Se carga el dataset en excel de Accidentes mortales
df_desgravamen= pd.read_excel('C:/data/Reporte de errores/446 - Desgravamen - 03.xlsx', sheet_name='Sheet1', 
                              dtype={'COD DE CERTIFICADO': str, 'DESCRIPCION ERROR': str, 'IDELOTE': str, 'CODIGO ERROR': str})

# %%
df_desgravamen.head(2)
# Out:
#    NRO LOTE LOTES ANTERIORES         FECHA CARGA  CODIGO PRODUCTO  \
# 0    872654              NaN 2022-10-25 17:52:43           3827.0
# 1    872654              NaN 2022-10-25 17:52:43           3827.0
#
#                        PRODUCTO  CODIGO PLAN   NOMBRE DE PLAN  \
# 0  Desgravamen + Desempleo BBVA      89705.0  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA      89705.0  Plan Contifacil
#
#      COD DE CERTIFICADO fecini_alta_CERTIFICADO fecfin_alta_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
#
#       IDEDET TIPO MOVIMIENTO FEC. INICIO    FEC. FIN MONEDA  SUMA ASEGURADA  \
# 0  556035505       Exclusion  30/12/2019  30/12/2022    SOL          2800.0
# 1  556035505       Exclusion  30/12/2019  30/12/2022    SOL          2800.0
#
#    TASA  TASA RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
#
#   APEMATERNO  FECNACIMIENTO  TIPDOCUMENTO NUMDOCUMENTO  \
# 0      MU?OZ     19880329.0           2.0     44994753
# 1      MU?OZ     19880329.0           2.0     44994753
#
#                       NOMBRE DE ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA TRAMA IDELOTE   IDEDET.1  \
# 0  901001108141740012031430011081410960091807101P...  872654  556035505
# 1  901001108141740012031430011081410960091807101P...  872654  556035505
#
#   ORIGEN ERROR CODIGO ERROR                                  DESCRIPCION ERROR
# 0  Error canal          986  EL NUMERO DE CERTIFICADO [00110814174001203143...
# 1  Error canal         2025  EL CAMPO FECEXCLUSION DEL(A) CERTIFICADO DEBE ...

# %%
df_desgravamen.columns = (
    df_desgravamen.columns
    .str.strip()  # quitar espacios al inicio/fin
    .str.upper()  # opcional: todo en mayúsculas
    .str.replace(r'[^A-Za-z0-9]', '_', regex=True)  # reemplazar todo lo que no sea letra/número/_ por _
)

# %%
df_desgravamen.drop(['IDELOTE','IDEDET_1','DESCRIPCION_ERROR'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df_desgravamen.drop(['IDELOTE','IDEDET_1','DESCRIPCION_ERROR'], axis=1, inplace=True)
#
# File c:\Users\nvelazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File c:\Users\nvelazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File c:\Users\nvelazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File c:\Users\nvelazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['IDELOTE', 'IDEDET_1', 'DESCRIPCION_ERROR'] not found in axis"

# %%
#df_desgravamen= df_desgravamen.rename(columns={'CODIGO_ERROR': 'TIPO_ERROR',
 #                                              'DESCRIPCION_ERROR': 'CODIGO_ERROR',
  #                                             'IDELOTE': 'TRAMA'}) # cambiar nombre de las columnas

# %%
#df_desgravamen= df_desgravamen[['CODIGO_PRODUCTO', 'LOTES_ANTERIORES','COD_DE_CERTIFICADO', 'FECINI_ALTA_CERTIFICADO', 
 #                               'FECFIN_ALTA_CERTIFICADO','IDEDET', 'TRAMA', 'TIPO_MOVIMIENTO', 'FEC__INICIO', 
  #                              'FEC__FIN', 'MONEDA', 'SUMA_ASEGURADA', 'TASA', 'PRIMABRUTACAN', 'PRIMANETACAN', 
   #                             'NOMBRE_DE_ARCHIVO', 'ORIGEN_ERROR', 'TIPO_ERROR', 'CODIGO_ERROR']]

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119541 entries, 0 to 119540
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   NRO_LOTE                 119541 non-null  int64
#  1   LOTES_ANTERIORES         876 non-null     object
#  2   FECHA_CARGA              119541 non-null  datetime64[ns]
#  3   CODIGO_PRODUCTO          119437 non-null  float64
#  4   PRODUCTO                 119437 non-null  object
#  5   CODIGO_PLAN              119437 non-null  float64
#  6   NOMBRE_DE_PLAN           119437 non-null  object
#  7   COD_DE_CERTIFICADO       119437 non-null  object
#  8   FECINI_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  10  IDEDET                   119541 non-null  int64
#  11  TIPO_MOVIMIENTO          119541 non-null  object
#  12  FEC__INICIO              118964 non-null  object
#  13  FEC__FIN                 118964 non-null  object
#  14  MONEDA                   119541 non-null  object
#  15  SUMA_ASEGURADA           119541 non-null  float64
#  16  TASA                     119541 non-null  float64
#  17  TASA_RECARGO             119541 non-null  float64
#  18  PRIMABRUTACAN            119541 non-null  float64
#  19  PRIMANETACAN             119541 non-null  float64
#  20  NOMCOMPLETO              118964 non-null  object
#  21  APEPATERNO               119541 non-null  object
#  22  APEMATERNO               119541 non-null  object
#  23  FECNACIMIENTO            118964 non-null  float64
#  24  TIPDOCUMENTO             118964 non-null  float64
#  25  NUMDOCUMENTO             118964 non-null  object
#  26  NOMBRE_DE_ARCHIVO        119541 non-null  object
#  27  LINEA_TRAMA              119541 non-null  object
#  28  ORIGEN_ERROR             119541 non-null  object
#  29  CODIGO_ERROR             119541 non-null  object
# dtypes: datetime64[ns](3), float64(9), int64(2), object(16)
# memory usage: 27.4+ MB

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, CODIGO_ERROR]
# Index: []

# %%
df_desgravamen['MONEDA'].value_counts()
# Out:
# MONEDA
# SOL    118616
# USD       925
# Name: count, dtype: int64

# %%
#df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'SUMA_ASEGURADA':0, 'TASA':0, 'PRIMABRUTACAN':0, 'PRIMANETACAN':0,
 #                                      'MONEDA': 'SIN DATO'})

# %%
df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'MONEDA': 'SIN DATO', 'ORIGEN_ERROR': 'SIN DATO', 'TIPDOCUMENTO':'SIN DATO'})
df_desgravamen.loc[df_desgravamen['MONEDA'] == 'nan', 'MONEDA'] = 'SIN DATO'
df_desgravamen.loc[df_desgravamen['ORIGEN_ERROR'] == 'nan', 'ORIGEN_ERROR'] = 'SIN DATO'

# %%
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)
df_desgravamen['FECHA_CARGA'] = pd.to_datetime(df_desgravamen['FECHA_CARGA'], errors='coerce')
df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["PRODUCTO"] = df_desgravamen["PRODUCTO"].astype(str)
df_desgravamen['CODIGO_PLAN'] = df_desgravamen['CODIGO_PLAN'].fillna(0).astype('int')
df_desgravamen["NOMBRE_DE_PLAN"] = df_desgravamen["NOMBRE_DE_PLAN"].astype(str)
df_desgravamen["COD_DE_CERTIFICADO"] = df_desgravamen["COD_DE_CERTIFICADO"].astype(str)
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen["TIPO_MOVIMIENTO"] = df_desgravamen["TIPO_MOVIMIENTO"].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['TASA_RECARGO'] = pd.to_numeric(df_desgravamen['TASA_RECARGO'], errors='coerce')
df_desgravamen['NOMCOMPLETO'] = df_desgravamen['NOMCOMPLETO'].astype(str)
df_desgravamen['APEPATERNO'] = df_desgravamen['APEPATERNO'].astype(str)
df_desgravamen['APEMATERNO'] = df_desgravamen['APEMATERNO'].astype(str)
df_desgravamen['FECNACIMIENTO'] = df_desgravamen['FECNACIMIENTO'].astype(str)
df_desgravamen['FECNACIMIENTO'] = pd.to_datetime(df_desgravamen['FECNACIMIENTO'], errors='coerce')
df_desgravamen["TIPDOCUMENTO"] = df_desgravamen["TIPDOCUMENTO"].astype(str)
df_desgravamen['NUMDOCUMENTO'] = df_desgravamen['NUMDOCUMENTO'].astype(str)
df_desgravamen['NOMBRE_DE_ARCHIVO'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].astype(str)
df_desgravamen['LINEA_TRAMA'] = df_desgravamen['LINEA_TRAMA'].astype(str)
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].astype(str)
df_desgravamen['CODIGO_ERROR'] = df_desgravamen['CODIGO_ERROR'].apply(lambda x: str(int(x)).zfill(4) if pd.notnull(x) else np.nan)
# Out:
# C:\Users\nvelazco\AppData\Local\Temp\ipykernel_12684\1175641090.py:19: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_desgravamen['FECNACIMIENTO'] = pd.to_datetime(df_desgravamen['FECNACIMIENTO'], errors='coerce')

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119541 entries, 0 to 119540
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   NRO_LOTE                 119541 non-null  int64
#  1   LOTES_ANTERIORES         119541 non-null  object
#  2   FECHA_CARGA              119541 non-null  datetime64[ns]
#  3   CODIGO_PRODUCTO          119541 non-null  int64
#  4   PRODUCTO                 119541 non-null  object
#  5   CODIGO_PLAN              119541 non-null  int64
#  6   NOMBRE_DE_PLAN           119541 non-null  object
#  7   COD_DE_CERTIFICADO       119541 non-null  object
#  8   FECINI_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  10  IDEDET                   119541 non-null  int64
#  11  TIPO_MOVIMIENTO          119541 non-null  object
#  12  FEC__INICIO              118964 non-null  datetime64[ns]
#  13  FEC__FIN                 118964 non-null  datetime64[ns]
#  14  MONEDA                   119541 non-null  object
#  15  SUMA_ASEGURADA           119541 non-null  float64
#  16  TASA                     119541 non-null  float64
#  17  TASA_RECARGO             119541 non-null  float64
#  18  PRIMABRUTACAN            119541 non-null  float64
#  19  PRIMANETACAN             119541 non-null  float64
#  20  NOMCOMPLETO              119541 non-null  object
#  21  APEPATERNO               119541 non-null  object
#  22  APEMATERNO               119541 non-null  object
#  23  FECNACIMIENTO            0 non-null       datetime64[ns]
#  24  TIPDOCUMENTO             119541 non-null  object
#  25  NUMDOCUMENTO             119541 non-null  object
#  26  NOMBRE_DE_ARCHIVO        119541 non-null  object
#  27  LINEA_TRAMA              119541 non-null  object
#  28  ORIGEN_ERROR             119541 non-null  object
#  29  CODIGO_ERROR             119541 non-null  object
# dtypes: datetime64[ns](6), float64(5), int64(4), object(15)
# memory usage: 27.4+ MB

# %%
df= df_desgravamen.copy()

# %%
df_desgravamen[df_desgravamen['LOTES_ANTERIORES']==""].head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    872654                  2022-10-25 17:52:43             3827
# 1    872654                  2022-10-25 17:52:43             3827
# 2    872654                  2022-10-25 17:52:43             3827
#
#                        PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN  \
# 0  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 2  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
#
#      COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
# 2  00110814184000055299              2016-09-26              2020-09-28
#
#       IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 0  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 1  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 2  556035940       Exclusion  2016-09-26 2020-09-28    SOL          6200.0
#
#    TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 2  0.35          0.35           2.17          2.11  JAIRO LUIS        FEIJOO
#
#     APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0        MU?OZ           NaT          2.0     44994753
# 1        MU?OZ           NaT          2.0     44994753
# 2  DEL ROSARIO           NaT          2.0     41618166
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
# 2  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR CODIGO_ERROR
# 0  901001108141740012031430011081410960091807101P...  Error canal         0986
# 1  901001108141740012031430011081410960091807101P...  Error canal         2025
# 2  901001108141840000552990011081416960004645701P...  Error canal         0843

# %%
df_desgravamen['ORIGEN_ERROR'].value_counts()
# Out:
# ORIGEN_ERROR
# Error Rimac    115901
# Error canal      3640
# Name: count, dtype: int64

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    872654                  2022-10-25 17:52:43             3827
# 1    872654                  2022-10-25 17:52:43             3827
# 2    872654                  2022-10-25 17:52:43             3827
#
#                        PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN  \
# 0  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 2  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
#
#      COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
# 2  00110814184000055299              2016-09-26              2020-09-28
#
#       IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 0  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 1  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 2  556035940       Exclusion  2016-09-26 2020-09-28    SOL          6200.0
#
#    TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 2  0.35          0.35           2.17          2.11  JAIRO LUIS        FEIJOO
#
#     APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0        MU?OZ           NaT          2.0     44994753
# 1        MU?OZ           NaT          2.0     44994753
# 2  DEL ROSARIO           NaT          2.0     41618166
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
# 2  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR CODIGO_ERROR
# 0  901001108141740012031430011081410960091807101P...  Error canal         0986
# 1  901001108141740012031430011081410960091807101P...  Error canal         2025
# 2  901001108141840000552990011081416960004645701P...  Error canal         0843

# %%
#df_desgravamen['COD_DE_CERTIFICADO'] = df_desgravamen['COD_DE_CERTIFICADO'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
"""df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)

df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['TIPO_MOVIMIENTO'] = df_desgravamen['TIPO_MOVIMIENTO'].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['SUMA_ASEGURADA']= pd.to_numeric(df_desgravamen['SUMA_ASEGURADA'], errors='coerce')
df_desgravamen['TASA']= pd.to_numeric(df_desgravamen['TASA'], errors='coerce')
df_desgravamen['PRIMABRUTACAN']= pd.to_numeric(df_desgravamen['PRIMABRUTACAN'], errors='coerce')
df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].fillna(0).astype('int')
"""
# Out:
# 'df_desgravamen[\'CODIGO_PRODUCTO\'] = df_desgravamen[\'CODIGO_PRODUCTO\'].fillna(0).astype(\'int\')\ndf_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)\n\ndf_desgravamen[\'FECINI_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECINI_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'TIPO_MOVIMIENTO\'] = df_desgravamen[\'TIPO_MOVIMIENTO\'].astype(str)\ndf_desgravamen[\'FEC__INICIO\'] = pd.to_datetime(df_desgravamen[\'FEC__INICIO\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'FEC__FIN\'] = pd.to_datetime(df_desgravamen[\'FEC__FIN\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'MONEDA\'] = df_desgravamen[\'MONEDA\'].astype(str)\ndf_desgravamen[\'SUMA_ASEGURADA\']= pd.to_numeric(df_desgravamen[\'SUMA_ASEGURADA\'], errors=\'coerce\')\ndf_desgravamen[\'TASA\']= pd.to_numeric(df_desgravamen[\'TASA\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMABRUTACAN\']= pd.to_numeric(df_desgravamen[\'PRIMABRUTACAN\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMANETACAN\']= pd.to_numeric(df_desgravamen[\'PRIMANETACAN\'], errors=\'coerce\')\ndf_desgravamen[\'ORIGEN_ERROR\'] = df_desgravamen[\'ORIGEN_ERROR\'].fillna(0).astype(\'int\')\n'

# %%
#TIPO MOVIMIENTO
df_desgravamen['FECINI_ALTA_CERTIFICADO'].value_counts()  # Counting occurrences of each unique value in the 'TIPO MOVIMIENTO' column
# Out:
# FECINI_ALTA_CERTIFICADO
# 2019-09-30    480
# 2019-09-27    460
# 2019-09-16    432
# 2017-09-28    348
# 2021-07-21    344
#              ...
# 2014-06-02      1
# 2013-11-14      1
# 2014-11-12      1
# 2014-09-11      1
# 2014-10-15      1
# Name: count, Length: 2095, dtype: int64

# %%
df_desgravamen[df_desgravamen['FEC__INICIO'].isna()].head(3)
# Out:
#        NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 27604     70140                  2016-05-11 13:00:14                0
# 27632     73976                  2016-07-06 23:40:21                0
# 27633     73976                  2016-07-06 23:40:21                0
#
#       PRODUCTO  CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO  \
# 27604      nan            0            nan                nan
# 27632      nan            0            nan                nan
# 27633      nan            0            nan                nan
#
#       FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET  \
# 27604                     NaT                     NaT  132857441
# 27632                     NaT                     NaT  141432028
# 27633                     NaT                     NaT  141432028
#
#       TIPO_MOVIMIENTO FEC__INICIO FEC__FIN    MONEDA  SUMA_ASEGURADA  TASA  \
# 27604  Sin Movimiento         NaT      NaT  SIN DATO             0.0   0.0
# 27632  Sin Movimiento         NaT      NaT       SOL             NaN   3.5
# 27633  Sin Movimiento         NaT      NaT       SOL             NaN   3.5
#
#       TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN   NOMCOMPLETO    APEPATERNO  \
# 27604            0            0.0           0.0           nan           nan
# 27632       1503.5            NaN           0.0  MARIA MIRTHA  DEL CASTILLO
# 27633       1503.5            NaN           0.0  MARIA MIRTHA  DEL CASTILLO
#
#       APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 27604        nan           NaT          NaN          nan
# 27632      PEREZ    1955-01-29            2       980724
# 27633      PEREZ    1955-01-29            2       980724
#
#                           NOMBRE_DE_ARCHIVO  \
# 27604  20100130204_0157001_20160511_001.TXT
# 27632  20100130204_0157001_20160706_003.TXT
# 27633  20100130204_0157001_20160706_003.TXT
#
#                                              LINEA_TRAMA ORIGEN_ERROR  \
# 27604  906001102755540002830710011027558960038589901P...  Error canal
# 27632  901001102995840000970580011029950960003682801P...  Error canal
# 27633  901001102995840000970580011029950960003682801P...  Error canal
#
#       CODIGO_ERROR                                  DESCRIPCION_ERROR
# 27604          983  ERROR, Al ser tipo de titular mancomuno debe h...
# 27632           76  EL CAMPO Fecha Inicio Vigencia TIENE UN FORMAT...
# 27633           76  EL CAMPO Fecha Fin Vigencia TIENE UN FORMATO Q...

# %%
#MONEDA
df_desgravamen['MONEDA'].value_counts()  # Counting occurrences of each unique value in the 'MONEDA' column
# Out:
# MONEDA
# SOL    118616
# USD       925
# Name: count, dtype: int64

# %%
df_desgravamen['TIPO_MOVIMIENTO'].value_counts()
# Out:
# TIPO_MOVIMIENTO
# Exclusion         119437
# Sin Movimiento       104
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['TIPO_MOVIMIENTO'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, CODIGO_ERROR]
# Index: []

# %%
df_desgravamen[df_desgravamen['MONEDA']=='SIN DATO'].head()
# Out:
#         NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 27604      70140                  2016-05-11 13:00:14                0
# 81303     130634                  2018-04-20 17:54:46                0
# 125160    285763                  2019-10-29 10:48:36             3827
#
#                             PRODUCTO  CODIGO_PLAN  \
# 27604                            nan            0
# 81303                            nan            0
# 125160  Desgravamen + Desempleo BBVA       157903
#
#                           NOMBRE_DE_PLAN COD_DE_CERTIFICADO  \
# 27604                                nan                nan
# 81303                                nan                nan
# 125160  PAN AMERICAN SILVER PERU TS BASE                  0
#
#        FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET  \
# 27604                      NaT                     NaT  132857441
# 81303                      NaT                     NaT  230834148
# 125160                     NaT                     NaT  335465001
#
#        TIPO_MOVIMIENTO FEC__INICIO FEC__FIN    MONEDA  SUMA_ASEGURADA  TASA  \
# 27604   Sin Movimiento         NaT      NaT  SIN DATO             0.0   0.0
# 81303   Sin Movimiento         NaT      NaT  SIN DATO             0.0   0.0
# 125160  Sin Movimiento         NaT      NaT  SIN DATO             0.0   0.0
#
#        TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO APEPATERNO  \
# 27604             0            0.0           0.0         nan        nan
# 81303             0            0.0           0.0         nan        nan
# 125160            0            0.0           0.0         nan        nan
#
#        APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 27604         nan           NaT          NaN          nan
# 81303         nan           NaT          NaN          nan
# 125160        nan           NaT          NaN          nan
#
#                            NOMBRE_DE_ARCHIVO  \
# 27604   20100130204_0157001_20160511_001.TXT
# 81303   20100130204_0157001_20180420_005.TXT
# 125160  20100130204_0157001_20191029_003.TXT
#
#                                               LINEA_TRAMA ORIGEN_ERROR  \
# 27604   906001102755540002830710011027558960038589901P...  Error canal
# 81303   903001103357340001273260011033574960008761301P...  Error canal
# 125160                                               9030  Error canal
#
#        CODIGO_ERROR                                  DESCRIPCION_ERROR
# 27604           983  ERROR, Al ser tipo de titular mancomuno debe h...
# 81303           983  ERROR, Al ser tipo de titular mancomuno debe h...
# 125160           12  ERROR EN CAMPO: TIPO MOVIMIENTO DEL(A) DEFECTO...

# %%
def extraer_fecha(fecha):
    try:
        fecha_str = fecha.split("_")[2]
        return datetime.strptime(fecha_str, "%Y%m%d").date()
    except Exception:
        return None  # En caso de error

# %%
# Aplicar a la columna
df_desgravamen['FECHA_TRAMA'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].apply(extraer_fecha)

# %%
df_desgravamen.head(2)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    872654                  2022-10-25 17:52:43             3827
# 1    872654                  2022-10-25 17:52:43             3827
#
#                        PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN  \
# 0  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
#
#      COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
#
#       IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 0  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 1  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
#
#    TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN NOMCOMPLETO    APEPATERNO  \
# 0  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
# 1  0.35          0.35           0.98          0.95      NEISER  IPARRAGUIRRE
#
#   APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0      MU?OZ           NaT          2.0     44994753
# 1      MU?OZ           NaT          2.0     44994753
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001108141740012031430011081410960091807101P...  Error canal
# 1  901001108141740012031430011081410960091807101P...  Error canal
#
#   CODIGO_ERROR FECHA_TRAMA
# 0         0986  2020-11-22
# 1         2025  2020-11-22

# %%
df_desgravamen['FECHA_TRAMA'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 119541 entries, 0 to 119540
# Series name: FECHA_TRAMA
# Non-Null Count   Dtype
# --------------   -----
# 119541 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 934.0 KB

# %%
df_desgravamen['FECHA_TRAMA']= pd.to_datetime(df_desgravamen['FECHA_TRAMA'], errors='coerce')

# %%
def clasificar(row):
    # Si lote no esta vacio
    if str(row['LOTES_ANTERIORES']).strip() != "":
        return 'Regularizacion no Exitosa'
    
    # Si último número del nombre de archivo > 100
    try:
        ultimo_numero = int(row['NOMBRE_DE_ARCHIVO'].split("_")[-1][:-4])
        if ultimo_numero > 100:
            return 'Regularizacion no Exitosa'
    except:
        pass
    
    # Si ninguna condición se cumple
    return 'Mes corriente'

# %%
nombre = '20100130204_0157001_20150409_001_41924.TXT'
numero= int(nombre.split("_")[-1][:-4])
print(numero)
# Out:
# 41924

# %%
#df_desgravamen['REGULARIZACION']= df_desgravamen['LOTES ANTERIORES'].notnull()
df_desgravamen['STATUS']= df_desgravamen.apply(clasificar, axis=1)

# %%
df_desgravamen['STATUS'].value_counts()
# Out:
# STATUS
# Regularizacion no Exitosa    119541
# Name: count, dtype: int64

# %%
df_desgravamen.head(10)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 0    872654                  2022-10-25 17:52:43             3827
# 1    872654                  2022-10-25 17:52:43             3827
# 2    872654                  2022-10-25 17:52:43             3827
# 3    872654                  2022-10-25 17:52:43             3827
# 4    872654                  2022-10-25 17:52:43             3827
# 5    872654                  2022-10-25 17:52:43             3827
# 6    872654                  2022-10-25 17:52:43             3827
# 7    872654                  2022-10-25 17:52:43             3827
# 8    872654                  2022-10-25 17:52:43             3827
# 9    872654                  2022-10-25 17:52:43             3827
#
#                        PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN  \
# 0  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 1  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 2  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 3  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 4  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 5  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 6  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 7  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 8  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
# 9  Desgravamen + Desempleo BBVA        89705  Plan Contifacil
#
#      COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 0  00110814174001203143              2019-12-30              2022-12-30
# 1  00110814174001203143              2019-12-30              2022-12-30
# 2  00110814184000055299              2016-09-26              2020-09-28
# 3  00110814184000055299              2016-09-26              2020-09-28
# 4  00110814184000668703              2018-12-30              2022-12-30
# 5  00110814184000668703              2018-12-30              2022-12-30
# 6  00110814184000028178              2016-05-18              2020-05-20
# 7  00110814184000028178              2016-05-18              2020-05-20
# 8  00110814184000113930              2017-03-16              2020-03-16
# 9  00110814184000113930              2017-03-16              2020-03-16
#
#       IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 0  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 1  556035505       Exclusion  2019-12-30 2022-12-30    SOL          2800.0
# 2  556035940       Exclusion  2016-09-26 2020-09-28    SOL          6200.0
# 3  556035941       Exclusion  2016-09-26 2020-09-28    SOL          6200.0
# 4  556036160       Exclusion  2018-12-30 2022-12-30    SOL          9500.0
# 5  556036160       Exclusion  2018-12-30 2022-12-30    SOL          9500.0
# 6  556035928       Exclusion  2016-05-18 2020-05-20    SOL         11400.0
# 7  556035929       Exclusion  2016-05-18 2020-05-20    SOL         11400.0
# 8  556035961       Exclusion  2017-03-16 2020-03-16    SOL          1000.0
# 9  556035962       Exclusion  2017-03-16 2020-03-16    SOL          1000.0
#
#    TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN      NOMCOMPLETO  \
# 0  0.35          0.35           0.98          0.95           NEISER
# 1  0.35          0.35           0.98          0.95           NEISER
# 2  0.35          0.35           2.17          2.11       JAIRO LUIS
# 3  0.35          0.35           2.17          2.11       JAIRO LUIS
# 4  0.35          0.35           3.33          3.23          MARIELA
# 5  0.35          0.35           3.33          3.23          MARIELA
# 6  0.35          0.35           3.99          3.87  WALTER SULLIVAN
# 7  0.35          0.35           3.99          3.87  WALTER SULLIVAN
# 8  0.35          0.35           0.35          0.34       FRANK ALEX
# 9  0.35          0.35           0.35          0.34       FRANK ALEX
#
#      APEPATERNO   APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 0  IPARRAGUIRRE        MU?OZ           NaT          2.0     44994753
# 1  IPARRAGUIRRE        MU?OZ           NaT          2.0     44994753
# 2        FEIJOO  DEL ROSARIO           NaT          2.0     41618166
# 3        FEIJOO  DEL ROSARIO           NaT          2.0     41618166
# 4       JIMENEZ       QUISPE           NaT          2.0     46058862
# 5       JIMENEZ       QUISPE           NaT          2.0     46058862
# 6        FELIPE       GASPAR           NaT          2.0     45797958
# 7        FELIPE       GASPAR           NaT          2.0     45797958
# 8        SALOME     ARZAPALO           NaT          2.0     42709169
# 9        SALOME     ARZAPALO           NaT          2.0     42709169
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_101.TXT
# 1  20100130204_0157001_20201122_101.TXT
# 2  20100130204_0157001_20201122_101.TXT
# 3  20100130204_0157001_20201122_101.TXT
# 4  20100130204_0157001_20201122_101.TXT
# 5  20100130204_0157001_20201122_101.TXT
# 6  20100130204_0157001_20201122_101.TXT
# 7  20100130204_0157001_20201122_101.TXT
# 8  20100130204_0157001_20201122_101.TXT
# 9  20100130204_0157001_20201122_101.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001108141740012031430011081410960091807101P...  Error canal
# 1  901001108141740012031430011081410960091807101P...  Error canal
# 2  901001108141840000552990011081416960004645701P...  Error canal
# 3  901001108141840000552990011081416960004645701P...  Error canal
# 4  901001108141840006687030011081417960044523801P...  Error canal
# 5  901001108141840006687030011081417960044523801P...  Error canal
# 6  901001108141840000281780011081419960002644801P...  Error canal
# 7  901001108141840000281780011081419960002644801P...  Error canal
# 8  901001108141840001139300011081412960009387001P...  Error canal
# 9  901001108141840001139300011081412960009387001P...  Error canal
#
#   CODIGO_ERROR FECHA_TRAMA                     STATUS
# 0         0986  2020-11-22  Regularizacion no Exitosa
# 1         2025  2020-11-22  Regularizacion no Exitosa
# 2         0843  2020-11-22  Regularizacion no Exitosa
# 3         0843  2020-11-22  Regularizacion no Exitosa
# 4         0986  2020-11-22  Regularizacion no Exitosa
# 5         2025  2020-11-22  Regularizacion no Exitosa
# 6         0843  2020-11-22  Regularizacion no Exitosa
# 7         0843  2020-11-22  Regularizacion no Exitosa
# 8         0843  2020-11-22  Regularizacion no Exitosa
# 9         0843  2020-11-22  Regularizacion no Exitosa

# %%
df_desgravamen[df_desgravamen['STATUS']=='Mes corriente'].head(6)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, CODIGO_ERROR, FECHA_TRAMA, STATUS]
# Index: []

# %%
df_errores['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 1068    1
# 0003    1
# 1155    1
# 1150    1
# 1152    1
# 1116    1
# 0114    1
# 7578    1
# 0199    1
# 0011    1
# 2395    1
# 1137    1
# 0163    1
# 0177    1
# 1154    1
# 0155    1
# 1153    1
# 1157    1
# 0117    1
# 1151    1
# 9964    1
# 1608    1
# 0193    1
# 0039    1
# 0034    1
# 0050    1
# 0940    1
# 0035    1
# 1143    1
# 9963    1
# 1045    1
# 0010    1
# 9969    1
# 7460    1
# 9978    1
# 7440    1
# 0130    1
# 0757    1
# 0141    1
# 0317    1
# 0119    1
# 1140    1
# 0852    1
# 0061    1
# 1083    1
# 0022    1
# 0005    1
# 1195    1
# 1135    1
# 8023    1
# 1052    1
# 1136    1
# Name: count, dtype: int64

# %%
df_errores[df_errores['CODIGO_ERROR'].isna()].head(10)
# Out:
#    CODIGO_ERROR        DESCRIPCION_ERROR            DETALLE         SOLUCION  \
# 11          NaN  ERROR EN CARGA DE TRAMA  NI ÉXITO NI ERROR  ANALISIS EMISOR
#
#    SOLUCION_2
# 11        NaN

# %%
df_errores[df_errores['CODIGO_ERROR'].isin({'2395','7440'})].head()
# Out:
#    CODIGO_ERROR DESCRIPCION_ERROR                       DETALLE  \
# 10         2395     ERROR DE TASA                          TASA
# 36         7440        ERROR EDAD  EDAD - MANCOMUNO INEXISTENTE
#
#              SOLUCION          SOLUCION_2
# 10    ANALISIS EMISOR   CONFIGURACION SAS
# 36  CONFIGURACION SAS  REGLAS POR CAMBIAR

# %%
df_errores[df_errores['CODIGO_ERROR']==' '].head()
# Out:
# Empty DataFrame
# Columns: [CODIGO_ERROR, DESCRIPCION_ERROR, DETALLE, SOLUCION, SOLUCION_2]
# Index: []

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR'].isna()].head(10)
# Out:
#       NRO_LOTE LOTES_ANTERIORES FECHA_CARGA  CODIGO_PRODUCTO  \
# 3713     43803                   2015-06-05             3070
# 3714     43803                   2015-06-05             3070
# 3715     43803                   2015-06-05             3070
# 3716     43803                   2015-06-05             3070
# 3717     43803                   2015-06-05             3070
# 3718     43803                   2015-06-05             3070
# 3719     43803                   2015-06-05             3070
# 3720     43803                   2015-06-05             3070
# 3721     43803                   2015-06-05             3070
# 3722     43803                   2015-06-05             3070
#
#               PRODUCTO  CODIGO_PLAN   NOMBRE_DE_PLAN    COD_DE_CERTIFICADO  \
# 3713  Desgravamen BBVA        60083  Plan Contifacil  00110643424000045901
# 3714  Desgravamen BBVA        60083  Plan Contifacil  00110327444000227556
# 3715  Desgravamen BBVA        60083  Plan Contifacil  00110609564000013494
# 3716  Desgravamen BBVA        60083  Plan Contifacil  00110831524000257714
# 3717  Desgravamen BBVA        60083  Plan Contifacil  00110716874000050235
# 3718  Desgravamen BBVA        60083  Plan Contifacil  00110249024000812242
# 3719  Desgravamen BBVA        60083  Plan Contifacil  00110323394000172679
# 3720  Desgravamen BBVA        60083  Plan Contifacil  00110165814000068342
# 3721  Desgravamen BBVA        60083  Plan Contifacil  00110195574000397854
# 3722  Desgravamen BBVA        60083  Plan Contifacil  00110232614000214881
#
#      FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO    IDEDET  \
# 3713              2014-08-11              2016-08-18  78905682
# 3714              2014-09-02              2018-09-03  78904998
# 3715              2014-05-26              2015-09-07  78905636
# 3716              2014-01-25              2017-01-30  78905995
# 3717              2014-10-06              2017-10-30  78905738
# 3718              2013-11-19              2015-05-04  78903828
# 3719              2014-06-12              2015-06-22  78904953
# 3720              2014-06-23              2017-06-26  78902507
# 3721              2014-04-25              2015-10-26  78902844
# 3722              2013-10-30              2016-10-31  78903464
#
#      TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  \
# 3713       Exclusion  2014-08-11 2016-08-18    SOL         20000.0  0.35
# 3714       Exclusion  2014-09-02 2018-09-03    SOL          3988.0  0.51
# 3715       Exclusion  2014-05-26 2015-09-07    SOL          3000.0  0.51
# 3716       Exclusion  2014-01-25 2017-01-30    SOL         70000.0  0.35
# 3717       Exclusion  2014-10-06 2017-10-30    SOL         12000.0  0.51
# 3718       Exclusion  2013-11-19 2015-05-04    SOL          5500.0  0.35
# 3719       Exclusion  2014-06-12 2015-06-22    SOL          5000.0  0.35
# 3720       Exclusion  2014-06-23 2017-06-26    SOL         20800.0  0.35
# 3721       Exclusion  2014-04-25 2015-10-26    SOL          1500.0  0.35
# 3722       Exclusion  2013-10-30 2016-10-31    SOL         30850.0  0.65
#
#      TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN           NOMCOMPLETO  \
# 3713         0.35           7.00          6.80         FREDY ORLANDO
# 3714         0.51           2.03          1.97                HEDWAR
# 3715         0.51           1.53          1.49          CARLOS EBERT
# 3716         0.35          24.50         23.79                CARLOS
# 3717         0.51           6.12          5.94  ANGEL EDUARDO FERNAN
# 3718         0.35           1.93          1.87      EUGENIO SANTIAGO
# 3719         0.35           1.75          1.70            IVAN ROGER
# 3720         0.35           7.28          7.07        MANUEL ALBERTO
# 3721         0.35           0.53          0.51          JORGE VICTOR
# 3722         0.65          20.05         19.47        VICTOR AURELIO
#
#      APEPATERNO  APEMATERNO FECNACIMIENTO TIPDOCUMENTO NUMDOCUMENTO  \
# 3713     TIPIAN       MATTA    1967-05-27            2     21851276
# 3714    DELGADO  DEL AGUILA    1971-02-26            2       973227
# 3715     CHAVEZ     LLERENA    1989-07-18            2     46265415
# 3716      HOYOS      VERTIZ    1957-08-20            2      7787762
# 3717      LAMAS    NECIOSUP    1989-02-13            2     45547225
# 3718   VALVERDE      LOZANO    1978-12-30            2     40365583
# 3719     ALFARO       REYES    1988-04-09            2     45426481
# 3720  CARAMUTTI     GAMARRA    1988-09-04            2     45451322
# 3721     ROMERO      ESLAVA    1954-11-02            2     43297740
# 3722    GAMARRA    VALDIVIA    1951-04-15            2      4411913
#
#                          NOMBRE_DE_ARCHIVO  \
# 3713  20100130204_0157001_20150605_003.TXT
# 3714  20100130204_0157001_20150605_003.TXT
# 3715  20100130204_0157001_20150605_003.TXT
# 3716  20100130204_0157001_20150605_003.TXT
# 3717  20100130204_0157001_20150605_003.TXT
# 3718  20100130204_0157001_20150605_003.TXT
# 3719  20100130204_0157001_20150605_003.TXT
# 3720  20100130204_0157001_20150605_003.TXT
# 3721  20100130204_0157001_20150605_003.TXT
# 3722  20100130204_0157001_20150605_003.TXT
#
#                                             LINEA_TRAMA ORIGEN_ERROR  \
# 3713  901001106434240000459010011064345960002888301P...     SIN DATO
# 3714  901001103274440002275560011032740960020627901P...     SIN DATO
# 3715  901001106095640000134940011060952960000423701P...     SIN DATO
# 3716  901001108315240002577140011083154960016632301P...     SIN DATO
# 3717  901001107168740000502350011071681960002604601P...     SIN DATO
# 3718  901001102490240008122420011024904960071496301P...     SIN DATO
# 3719  901001103233940001726790011032332960010922001P...     SIN DATO
# 3720  901001101658140000683420011016584960008889601P...     SIN DATO
# 3721  901001101955740003978540011019554960013940001P...     SIN DATO
# 3722  901001102326140002148810011023267960032666901P...     SIN DATO
#
#      CODIGO_ERROR DESCRIPCION_ERROR FECHA_TRAMA         STATUS
# 3713          NaN               nan  2015-06-05  Mes corriente
# 3714          NaN               nan  2015-06-05  Mes corriente
# 3715          NaN               nan  2015-06-05  Mes corriente
# 3716          NaN               nan  2015-06-05  Mes corriente
# 3717          NaN               nan  2015-06-05  Mes corriente
# 3718          NaN               nan  2015-06-05  Mes corriente
# 3719          NaN               nan  2015-06-05  Mes corriente
# 3720          NaN               nan  2015-06-05  Mes corriente
# 3721          NaN               nan  2015-06-05  Mes corriente
# 3722          NaN               nan  2015-06-05  Mes corriente

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR']==''].head()
# Out:
# Empty DataFrame
# Columns: [CODIGO_PRODUCTO, LOTES_ANTERIORES, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TRAMA, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, PRIMABRUTACAN, PRIMANETACAN, NOMBRE_DE_ARCHIVO, ORIGEN_ERROR, TIPO_ERROR, CODIGO_ERROR, FECHA_TRAMA, STATUS]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       52 non-null     object
#  1   DESCRIPCION_ERROR  53 non-null     object
#  2   DETALLE            53 non-null     object
#  3   SOLUCION           53 non-null     object
#  4   SOLUCION_2         19 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
df= df_desgravamen.merge(df_errores, on='CODIGO_ERROR', how='left')

# %%
df['DESCRIPCION_ERROR'].value_counts()
# Out:
# DESCRIPCION_ERROR
# CAMPOS EN BLANCO              253
# PAGO PENDIENTE DE CORREGIR     18
# Name: count, dtype: int64

# %%
df['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 1106    115762
# 0970      1400
# 0843       853
# 0986       327
# 2025       313
# 0014       235
# 0035       233
# 1201       134
# 0983       104
# 0101        91
# 1092        48
# 1135        20
# 1143        18
# 1200         2
# 1215         1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119541 entries, 0 to 119540
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   NRO_LOTE                 119541 non-null  int64
#  1   LOTES_ANTERIORES         119541 non-null  object
#  2   FECHA_CARGA              119541 non-null  datetime64[ns]
#  3   CODIGO_PRODUCTO          119541 non-null  int64
#  4   PRODUCTO                 119541 non-null  object
#  5   CODIGO_PLAN              119541 non-null  int64
#  6   NOMBRE_DE_PLAN           119541 non-null  object
#  7   COD_DE_CERTIFICADO       119541 non-null  object
#  8   FECINI_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  117979 non-null  datetime64[ns]
#  10  IDEDET                   119541 non-null  int64
#  11  TIPO_MOVIMIENTO          119541 non-null  object
#  12  FEC__INICIO              118964 non-null  datetime64[ns]
#  13  FEC__FIN                 118964 non-null  datetime64[ns]
#  14  MONEDA                   119541 non-null  object
#  15  SUMA_ASEGURADA           119541 non-null  float64
#  16  TASA                     119541 non-null  float64
#  17  TASA_RECARGO             119541 non-null  float64
#  18  PRIMABRUTACAN            119541 non-null  float64
#  19  PRIMANETACAN             119541 non-null  float64
#  20  NOMCOMPLETO              119541 non-null  object
#  21  APEPATERNO               119541 non-null  object
#  22  APEMATERNO               119541 non-null  object
#  23  FECNACIMIENTO            0 non-null       datetime64[ns]
#  24  TIPDOCUMENTO             119541 non-null  object
#  25  NUMDOCUMENTO             119541 non-null  object
#  26  NOMBRE_DE_ARCHIVO        119541 non-null  object
#  27  LINEA_TRAMA              119541 non-null  object
#  28  ORIGEN_ERROR             119541 non-null  object
#  29  CODIGO_ERROR             119541 non-null  object
#  30  FECHA_TRAMA              119541 non-null  datetime64[ns]
#  31  STATUS                   119541 non-null  object
#  32  DESCRIPCION_ERROR        271 non-null     object
#  33  DETALLE                  271 non-null     object
#  34  SOLUCION                 271 non-null     object
#  35  SOLUCION_2               0 non-null       object
# dtypes: datetime64[ns](7), float64(5), int64(4), object(20)
# memory usage: 32.8+ MB
