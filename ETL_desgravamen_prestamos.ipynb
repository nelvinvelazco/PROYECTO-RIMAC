# %%
import pandas as pd
from datetime import datetime
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
import unicodedata
import os
pd.set_option('display.max_columns', None)

# %%
df_errores= pd.read_excel('c:/data/tabla_errores.xlsx', sheet_name='Sheet1', dtype={'CODIGO_ERROR': str})
df_errores.head(3)
# Out:
#   CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1         0003                            ERROR EN CARGA DE TRAMA
# 2         1155                         TRAMA REPETIDA O DUPLICADA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
# 2                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION_2
# 0  ANULAR MASIVAS
# 1             NaN
# 2  ANULAR MASIVAS

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       52 non-null     object
#  1   DESCRIPCION_ERROR  53 non-null     object
#  2   DETALLE            53 non-null     object
#  3   SOLUCION           53 non-null     object
#  4   SOLUCION_2         19 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
#df_errores.to_excel('c:/data/tabla_errores.xlsx', index=False)

# %%
# Se carga el dataset en excel de Accidentes mortales
df_desgravamen= pd.read_excel('C:/data/Reporte de errores/446 - Desgravamen - 02.xlsx', sheet_name='Sheet1', 
                              dtype={'COD DE CERTIFICADO': str, 'DESCRIPCION ERROR': str, 'IDELOTE': str, 'CODIGO ERROR': str})

# %%
df_desgravamen.head(2)
# Out:
#    NRO LOTE  LOTES ANTERIORES         FECHA CARGA  CODIGO PRODUCTO PRODUCTO  \
# 0    872611               NaN 2022-10-25 17:10:46              NaN      NaN
# 1    872611               NaN 2022-10-25 17:10:46              NaN      NaN
#
#    CODIGO PLAN NOMBRE DE PLAN COD DE CERTIFICADO fecini_alta_CERTIFICADO  \
# 0          NaN            NaN                NaN                     NaT
# 1          NaN            NaN                NaN                     NaT
#
#   fecfin_alta_CERTIFICADO     IDEDET TIPO MOVIMIENTO FEC. INICIO    FEC. FIN  \
# 0                     NaT  555862169  Sin Movimiento  03/03/2020  17/06/2024
# 1                     NaT  555862263  Sin Movimiento  30/04/2018  05/04/2021
#
#   MONEDA  SUMA ASEGURADA  TASA  TASA RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
#
#   NOMCOMPLETO  APEPATERNO APEMATERNO  FECNACIMIENTO  TIPDOCUMENTO  \
# 0     GABRIEL     SALINAS       LORA       19790130             2
# 1        JUAN  SANTILLANA  CALLIRGOS       19491019             2
#
#   NUMDOCUMENTO                     NOMBRE DE ARCHIVO  \
# 0     40227891  20100130204_0157001_20201122_100.TXT
# 1     09295733  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA TRAMA IDELOTE   IDEDET.1  \
# 0  901001101062040002365100011010629960014659201P...  872611  555862169
# 1  901001101062940001863270011010626960011202701P...  872611  555862263
#
#   ORIGEN ERROR CODIGO ERROR           DESCRIPCION ERROR
# 0  Error canal         1158  Trama repetida o duplicada
# 1  Error canal         1158  Trama repetida o duplicada

# %%
df_desgravamen.columns = (
    df_desgravamen.columns
    .str.strip()  # quitar espacios al inicio/fin
    .str.upper()  # opcional: todo en mayúsculas
    .str.replace(r'[^A-Za-z0-9]', '_', regex=True)  # reemplazar todo lo que no sea letra/número/_ por _
)

# %%
df_desgravamen.drop(['IDELOTE','IDEDET_1'], axis=1, inplace=True)

# %%
#df_desgravamen= df_desgravamen.rename(columns={'CODIGO_ERROR': 'TIPO_ERROR',
 #                                              'DESCRIPCION_ERROR': 'CODIGO_ERROR',
  #                                             'IDELOTE': 'TRAMA'}) # cambiar nombre de las columnas

# %%
#df_desgravamen= df_desgravamen[['CODIGO_PRODUCTO', 'LOTES_ANTERIORES','COD_DE_CERTIFICADO', 'FECINI_ALTA_CERTIFICADO', 
 #                               'FECFIN_ALTA_CERTIFICADO','IDEDET', 'TRAMA', 'TIPO_MOVIMIENTO', 'FEC__INICIO', 
  #                              'FEC__FIN', 'MONEDA', 'SUMA_ASEGURADA', 'TASA', 'PRIMABRUTACAN', 'PRIMANETACAN', 
   #                             'NOMBRE_DE_ARCHIVO', 'ORIGEN_ERROR', 'TIPO_ERROR', 'CODIGO_ERROR']]

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97770 entries, 0 to 97769
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_LOTE                 97770 non-null  int64
#  1   LOTES_ANTERIORES         4 non-null      float64
#  2   FECHA_CARGA              97770 non-null  datetime64[ns]
#  3   CODIGO_PRODUCTO          97337 non-null  float64
#  4   PRODUCTO                 97337 non-null  object
#  5   CODIGO_PLAN              97337 non-null  float64
#  6   NOMBRE_DE_PLAN           97337 non-null  object
#  7   COD_DE_CERTIFICADO       97337 non-null  object
#  8   FECINI_ALTA_CERTIFICADO  95773 non-null  datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  95773 non-null  datetime64[ns]
#  10  IDEDET                   97770 non-null  int64
#  11  TIPO_MOVIMIENTO          97770 non-null  object
#  12  FEC__INICIO              97770 non-null  object
#  13  FEC__FIN                 97770 non-null  object
#  14  MONEDA                   97770 non-null  object
#  15  SUMA_ASEGURADA           97770 non-null  float64
#  16  TASA                     97770 non-null  float64
#  17  TASA_RECARGO             97770 non-null  float64
#  18  PRIMABRUTACAN            97770 non-null  float64
#  19  PRIMANETACAN             97770 non-null  float64
#  20  NOMCOMPLETO              97770 non-null  object
#  21  APEPATERNO               97770 non-null  object
#  22  APEMATERNO               97770 non-null  object
#  23  FECNACIMIENTO            97770 non-null  int64
#  24  TIPDOCUMENTO             97770 non-null  int64
#  25  NUMDOCUMENTO             97770 non-null  object
#  26  NOMBRE_DE_ARCHIVO        97770 non-null  object
#  27  LINEA_TRAMA              97770 non-null  object
#  28  ORIGEN_ERROR             97770 non-null  object
#  29  CODIGO_ERROR             97770 non-null  object
#  30  DESCRIPCION_ERROR        97770 non-null  object
# dtypes: datetime64[ns](3), float64(8), int64(4), object(16)
# memory usage: 23.1+ MB

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, CODIGO_ERROR, DESCRIPCION_ERROR]
# Index: []

# %%
df_desgravamen[df_desgravamen['COD_DE_CERTIFICADO'].notnull()].head(3)
# Out:
#      NRO_LOTE  LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO  \
# 433    872611               NaN 2022-10-25 17:10:46           3827.0
# 434    872611               NaN 2022-10-25 17:10:46           3827.0
# 435    872611               NaN 2022-10-25 17:10:46           3827.0
#
#                          PRODUCTO  CODIGO_PLAN  NOMBRE_DE_PLAN  \
# 433  Desgravamen + Desempleo BBVA      80908.0  Plan Conticasa
# 434  Desgravamen + Desempleo BBVA      80908.0  Plan Conticasa
# 435  Desgravamen + Desempleo BBVA      80908.0  Plan Conticasa
#
#        COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO  \
# 433  00110358944000291156              2020-01-22              2039-03-29
# 434  00110358944000291156              2020-01-22              2039-03-29
# 435  00110732524000101058              2020-05-28              2031-07-26
#
#         IDEDET TIPO_MOVIMIENTO FEC__INICIO    FEC__FIN MONEDA  SUMA_ASEGURADA  \
# 433  555923543       Exclusion  22/01/2020  30/03/2039    SOL        639100.0
# 434  555923543       Exclusion  22/01/2020  30/03/2039    SOL        639100.0
# 435  555924360       Exclusion  28/05/2020  02/09/2031    SOL        489887.2
#
#      TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN    NOMCOMPLETO  \
# 433  0.28         50.28         268.43        260.61         ELBERT
# 434  0.28         50.28         268.43        260.61         ELBERT
# 435  0.28          0.28         137.17        133.17  GUIDO EDMUNDO
#
#     APEPATERNO APEMATERNO  FECNACIMIENTO  TIPDOCUMENTO NUMDOCUMENTO  \
# 433     AGURTO   MOGOLLON       19590330             2     06103897
# 434     AGURTO   MOGOLLON       19590330             2     06103897
# 435     MORENO   COLLAZOS       19510727             2     06760705
#
#                         NOMBRE_DE_ARCHIVO  \
# 433  20100130204_0157001_20201122_100.TXT
# 434  20100130204_0157001_20201122_100.TXT
# 435  20100130204_0157001_20201122_100.TXT
#
#                                            LINEA_TRAMA ORIGEN_ERROR  \
# 433  903001103589440002911560011035895960021558701P...  Error Rimac
# 434  903001103589440002911560011035895960021558701P...  Error Rimac
# 435  903001107325240001010580011073257960005563901P...  Error Rimac
#
#      CODIGO_ERROR                                  DESCRIPCION_ERROR
# 433           101  No se identifico IdeAcuerdo IAA para el Acuerd...
# 434           101  No se identifico IdeAcuerdo IAA para el Acuerd...
# 435           101  No se identifico IdeAcuerdo IAA para el Acuerd...

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE  LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO PRODUCTO  \
# 0    872611               NaN 2022-10-25 17:10:46              NaN      NaN
# 1    872611               NaN 2022-10-25 17:10:46              NaN      NaN
# 2    872611               NaN 2022-10-25 17:10:46              NaN      NaN
#
#    CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0          NaN            NaN                NaN                     NaT
# 1          NaN            NaN                NaN                     NaT
# 2          NaN            NaN                NaN                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO FEC__INICIO    FEC__FIN  \
# 0                     NaT  555862169  Sin Movimiento  03/03/2020  17/06/2024
# 1                     NaT  555862263  Sin Movimiento  30/04/2018  05/04/2021
# 2                     NaT  555862419  Sin Movimiento  06/03/2018  02/03/2021
#
#   MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
# 2    SOL         6200.00  0.35          0.35           2.17          2.11
#
#      NOMCOMPLETO  APEPATERNO APEMATERNO  FECNACIMIENTO  TIPDOCUMENTO  \
# 0        GABRIEL     SALINAS       LORA       19790130             2
# 1           JUAN  SANTILLANA  CALLIRGOS       19491019             2
# 2  JESUS EDUARDO       LOPEZ   FERREYRA       19920328             2
#
#   NUMDOCUMENTO                     NOMBRE_DE_ARCHIVO  \
# 0     40227891  20100130204_0157001_20201122_100.TXT
# 1     09295733  20100130204_0157001_20201122_100.TXT
# 2     46923835  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001101062040002365100011010629960014659201P...  Error canal
# 1  901001101062940001863270011010626960011202701P...  Error canal
# 2  901001101096240003050550011010969960024944401P...  Error canal
#
#    CODIGO_ERROR           DESCRIPCION_ERROR
# 0          1158  Trama repetida o duplicada
# 1          1158  Trama repetida o duplicada
# 2          1158  Trama repetida o duplicada

# %%
df_desgravamen['MONEDA'].value_counts()
# Out:
# MONEDA
# SOL    96880
# USD      890
# Name: count, dtype: int64

# %%
#df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'SUMA_ASEGURADA':0, 'TASA':0, 'PRIMABRUTACAN':0, 'PRIMANETACAN':0,
 #                                      'MONEDA': 'SIN DATO'})

# %%
df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':''})

# %%
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)
df_desgravamen['FECHA_CARGA'] = pd.to_datetime(df_desgravamen['FECHA_CARGA'], errors='coerce')
df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["PRODUCTO"] = df_desgravamen["PRODUCTO"].astype(str)
df_desgravamen['CODIGO_PLAN'] = df_desgravamen['CODIGO_PLAN'].fillna(0).astype('int')
df_desgravamen["NOMBRE_DE_PLAN"] = df_desgravamen["NOMBRE_DE_PLAN"].astype(str)
df_desgravamen["COD_DE_CERTIFICADO"] = df_desgravamen["COD_DE_CERTIFICADO"].astype(str)
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen["TIPO_MOVIMIENTO"] = df_desgravamen["TIPO_MOVIMIENTO"].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['NOMCOMPLETO'] = df_desgravamen['NOMCOMPLETO'].astype(str)
df_desgravamen['APEPATERNO'] = df_desgravamen['APEPATERNO'].astype(str)
df_desgravamen['APEMATERNO'] = df_desgravamen['APEMATERNO'].astype(str)
df_desgravamen['FECNACIMIENTO'] = df_desgravamen['FECNACIMIENTO'].astype(str)
df_desgravamen['FECNACIMIENTO'] = pd.to_datetime(df_desgravamen['FECNACIMIENTO'], errors='coerce').dt.date
df_desgravamen['NUMDOCUMENTO'] = df_desgravamen['NUMDOCUMENTO'].astype(str)
df_desgravamen['NOMBRE_DE_ARCHIVO'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].astype(str)
df_desgravamen['LINEA_TRAMA'] = df_desgravamen['LINEA_TRAMA'].astype(str)
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].astype(str)
#df_desgravamen['CODIGO_ERROR'] = df_desgravamen['CODIGO_ERROR'].astype(str)
df_desgravamen['DESCRIPCION_ERROR'] = df_desgravamen['DESCRIPCION_ERROR'].astype(str)

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97770 entries, 0 to 97769
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO_LOTE                 97770 non-null  int64
#  1   LOTES_ANTERIORES         97770 non-null  object
#  2   FECHA_CARGA              97770 non-null  datetime64[ns]
#  3   CODIGO_PRODUCTO          97770 non-null  int64
#  4   PRODUCTO                 97770 non-null  object
#  5   CODIGO_PLAN              97770 non-null  int64
#  6   NOMBRE_DE_PLAN           97770 non-null  object
#  7   COD_DE_CERTIFICADO       97770 non-null  object
#  8   FECINI_ALTA_CERTIFICADO  95773 non-null  datetime64[ns]
#  9   FECFIN_ALTA_CERTIFICADO  95773 non-null  datetime64[ns]
#  10  IDEDET                   97770 non-null  int64
#  11  TIPO_MOVIMIENTO          97770 non-null  object
#  12  FEC__INICIO              97770 non-null  datetime64[ns]
#  13  FEC__FIN                 97770 non-null  datetime64[ns]
#  14  MONEDA                   97770 non-null  object
#  15  SUMA_ASEGURADA           97770 non-null  float64
#  16  TASA                     97770 non-null  float64
#  17  TASA_RECARGO             97770 non-null  float64
#  18  PRIMABRUTACAN            97770 non-null  float64
#  19  PRIMANETACAN             97770 non-null  float64
#  20  NOMCOMPLETO              97770 non-null  object
#  21  APEPATERNO               97770 non-null  object
#  22  APEMATERNO               97770 non-null  object
#  23  FECNACIMIENTO            97770 non-null  object
#  24  TIPDOCUMENTO             97770 non-null  int64
#  25  NUMDOCUMENTO             97770 non-null  object
#  26  NOMBRE_DE_ARCHIVO        97770 non-null  object
#  27  LINEA_TRAMA              97770 non-null  object
#  28  ORIGEN_ERROR             97770 non-null  object
#  29  CODIGO_ERROR             97770 non-null  object
#  30  DESCRIPCION_ERROR        97770 non-null  object
# dtypes: datetime64[ns](5), float64(5), int64(5), object(16)
# memory usage: 23.1+ MB

# %%
df= df_desgravamen.copy()

# %%
df_desgravamen[df_desgravamen['ORIGEN_ERROR'].isna()].head(3)
# Out:
# Empty DataFrame
# Columns: [NRO_LOTE, LOTES_ANTERIORES, FECHA_CARGA, CODIGO_PRODUCTO, PRODUCTO, CODIGO_PLAN, NOMBRE_DE_PLAN, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, TASA_RECARGO, PRIMABRUTACAN, PRIMANETACAN, NOMCOMPLETO, APEPATERNO, APEMATERNO, FECNACIMIENTO, TIPDOCUMENTO, NUMDOCUMENTO, NOMBRE_DE_ARCHIVO, LINEA_TRAMA, ORIGEN_ERROR, CODIGO_ERROR, DESCRIPCION_ERROR]
# Index: []

# %%
df_desgravamen['ORIGEN_ERROR'].value_counts()
# Out:
# ORIGEN_ERROR
# Error Rimac    95896
# Error canal     1874
# Name: count, dtype: int64

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO PRODUCTO  \
# 0    872611                  2022-10-25 17:10:46                0      nan
# 1    872611                  2022-10-25 17:10:46                0      nan
# 2    872611                  2022-10-25 17:10:46                0      nan
#
#    CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0            0            nan                nan                     NaT
# 1            0            nan                nan                     NaT
# 2            0            nan                nan                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN  \
# 0                     NaT  555862169  Sin Movimiento  2020-03-03 2024-06-17
# 1                     NaT  555862263  Sin Movimiento  2018-04-30 2021-04-05
# 2                     NaT  555862419  Sin Movimiento  2018-03-06 2021-03-02
#
#   MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
# 2    SOL         6200.00  0.35          0.35           2.17          2.11
#
#      NOMCOMPLETO  APEPATERNO APEMATERNO FECNACIMIENTO  TIPDOCUMENTO  \
# 0        GABRIEL     SALINAS       LORA      19790130             2
# 1           JUAN  SANTILLANA  CALLIRGOS      19491019             2
# 2  JESUS EDUARDO       LOPEZ   FERREYRA      19920328             2
#
#   NUMDOCUMENTO                     NOMBRE_DE_ARCHIVO  \
# 0     40227891  20100130204_0157001_20201122_100.TXT
# 1     09295733  20100130204_0157001_20201122_100.TXT
# 2     46923835  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001101062040002365100011010629960014659201P...  Error canal
# 1  901001101062940001863270011010626960011202701P...  Error canal
# 2  901001101096240003050550011010969960024944401P...  Error canal
#
#    CODIGO_ERROR           DESCRIPCION_ERROR
# 0          1158  Trama repetida o duplicada
# 1          1158  Trama repetida o duplicada
# 2          1158  Trama repetida o duplicada

# %%
#df_desgravamen['COD_DE_CERTIFICADO'] = df_desgravamen['COD_DE_CERTIFICADO'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
"""df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)

df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['TIPO_MOVIMIENTO'] = df_desgravamen['TIPO_MOVIMIENTO'].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['SUMA_ASEGURADA']= pd.to_numeric(df_desgravamen['SUMA_ASEGURADA'], errors='coerce')
df_desgravamen['TASA']= pd.to_numeric(df_desgravamen['TASA'], errors='coerce')
df_desgravamen['PRIMABRUTACAN']= pd.to_numeric(df_desgravamen['PRIMABRUTACAN'], errors='coerce')
df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].fillna(0).astype('int')
"""
# Out:
# 'df_desgravamen[\'CODIGO_PRODUCTO\'] = df_desgravamen[\'CODIGO_PRODUCTO\'].fillna(0).astype(\'int\')\ndf_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)\n\ndf_desgravamen[\'FECINI_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECINI_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'] = pd.to_datetime(df_desgravamen[\'FECFIN_ALTA_CERTIFICADO\'], errors=\'coerce\')\ndf_desgravamen[\'TIPO_MOVIMIENTO\'] = df_desgravamen[\'TIPO_MOVIMIENTO\'].astype(str)\ndf_desgravamen[\'FEC__INICIO\'] = pd.to_datetime(df_desgravamen[\'FEC__INICIO\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'FEC__FIN\'] = pd.to_datetime(df_desgravamen[\'FEC__FIN\'], format=\'%d/%m/%Y\', errors=\'coerce\')\ndf_desgravamen[\'MONEDA\'] = df_desgravamen[\'MONEDA\'].astype(str)\ndf_desgravamen[\'SUMA_ASEGURADA\']= pd.to_numeric(df_desgravamen[\'SUMA_ASEGURADA\'], errors=\'coerce\')\ndf_desgravamen[\'TASA\']= pd.to_numeric(df_desgravamen[\'TASA\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMABRUTACAN\']= pd.to_numeric(df_desgravamen[\'PRIMABRUTACAN\'], errors=\'coerce\')\ndf_desgravamen[\'PRIMANETACAN\']= pd.to_numeric(df_desgravamen[\'PRIMANETACAN\'], errors=\'coerce\')\ndf_desgravamen[\'ORIGEN_ERROR\'] = df_desgravamen[\'ORIGEN_ERROR\'].fillna(0).astype(\'int\')\n'

# %%
df_desgravamen[df_desgravamen['FECINI_ALTA_CERTIFICADO'].isnull()]['FECINI_ALTA_CERTIFICADO'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#TIPO MOVIMIENTO
df_desgravamen['FECINI_ALTA_CERTIFICADO'].value_counts()  # Counting occurrences of each unique value in the 'TIPO MOVIMIENTO' column
# Out:
# FECINI_ALTA_CERTIFICADO
# 2015-03-31    134
# 2014-12-30    124
# 2015-05-29    114
# 2015-10-30    106
# 2015-07-31    105
#              ...
# 2012-08-23      1
# 2013-01-08      1
# 2013-05-08      1
# 2013-03-11      1
# 2017-01-15      1
# Name: count, Length: 1161, dtype: int64

# %%
#MONEDA
df_desgravamen['MONEDA'].value_counts()  # Counting occurrences of each unique value in the 'MONEDA' column
# Out:
# MONEDA
# SOL         46356
# USD          4302
# SIN DATO        1
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['MONEDA']=='SIN DATO'].head()
# Out:
#        CODIGO_PRODUCTO LOTES_ANTERIORES COD_DE_CERTIFICADO  \
# 46033                0                                 NaN
#
#       FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET  \
# 46033                     NaT                     NaT  132857441
#
#                                                    TRAMA TIPO_MOVIMIENTO  \
# 46033  906001102755540002830710011027558960038589901P...  Sin Movimiento
#
#       FEC__INICIO FEC__FIN    MONEDA  SUMA_ASEGURADA  TASA  PRIMABRUTACAN  \
# 46033         NaT      NaT  SIN DATO             0.0   0.0            0.0
#
#        PRIMANETACAN                     NOMBRE_DE_ARCHIVO  ORIGEN_ERROR  \
# 46033           0.0  20100130204_0157001_20160511_001.TXT     132857441
#
#         TIPO_ERROR CODIGO_ERROR
# 46033  Error canal          193

# %%
def extraer_fecha(fecha):
    try:
        fecha_str = fecha.split("_")[2]
        return datetime.strptime(fecha_str, "%Y%m%d").date()
    except Exception:
        return None  # En caso de error

# %%
# Aplicar a la columna
df_desgravamen['FECHA_TRAMA'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].apply(extraer_fecha)

# %%
df_desgravamen.head(2)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO PRODUCTO  \
# 0    872611                  2022-10-25 17:10:46                0      nan
# 1    872611                  2022-10-25 17:10:46                0      nan
#
#    CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0            0            nan                nan                     NaT
# 1            0            nan                nan                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN  \
# 0                     NaT  555862169  Sin Movimiento  2020-03-03 2024-06-17
# 1                     NaT  555862263  Sin Movimiento  2018-04-30 2021-04-05
#
#   MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
#
#   NOMCOMPLETO  APEPATERNO APEMATERNO FECNACIMIENTO  TIPDOCUMENTO NUMDOCUMENTO  \
# 0     GABRIEL     SALINAS       LORA      19790130             2     40227891
# 1        JUAN  SANTILLANA  CALLIRGOS      19491019             2     09295733
#
#                       NOMBRE_DE_ARCHIVO  \
# 0  20100130204_0157001_20201122_100.TXT
# 1  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001101062040002365100011010629960014659201P...  Error canal
# 1  901001101062940001863270011010626960011202701P...  Error canal
#
#   CODIGO_ERROR           DESCRIPCION_ERROR FECHA_TRAMA
# 0         1158  Trama repetida o duplicada  2020-11-22
# 1         1158  Trama repetida o duplicada  2020-11-22

# %%
df_desgravamen['FECHA_TRAMA'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 97770 entries, 0 to 97769
# Series name: FECHA_TRAMA
# Non-Null Count  Dtype
# --------------  -----
# 97770 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 764.0 KB

# %%
df_desgravamen['FECHA_TRAMA']= pd.to_datetime(df_desgravamen['FECHA_TRAMA'], errors='coerce')

# %%
def clasificar(row):
    # Si lote no esta vacio
    if str(row['LOTES_ANTERIORES']).strip() != "":
        return 'Regularizacion no Exitosa'
    
    # Si último número del nombre de archivo > 100
    try:
        ultimo_numero = int(row['NOMBRE_DE_ARCHIVO'].split("_")[-1][:-4])
        if ultimo_numero > 100:
            return 'Regularizacion no Exitosa'
    except:
        pass
    
    # Si ninguna condición se cumple
    return 'Mes corriente'

# %%
nombre = '20100130204_0157001_20150409_001_41924.TXT'
numero= int(nombre.split("_")[-1][:-4])
print(numero)
# Out:
# 41924

# %%
#df_desgravamen['REGULARIZACION']= df_desgravamen['LOTES ANTERIORES'].notnull()
df_desgravamen['STATUS']= df_desgravamen.apply(clasificar, axis=1)

# %%
df_desgravamen['STATUS'].value_counts()
# Out:
# STATUS
# Mes corriente                97766
# Regularizacion no Exitosa        4
# Name: count, dtype: int64

# %%
df_desgravamen.head(5)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO PRODUCTO  \
# 0    872611                  2022-10-25 17:10:46                0      nan
# 1    872611                  2022-10-25 17:10:46                0      nan
# 2    872611                  2022-10-25 17:10:46                0      nan
# 3    872611                  2022-10-25 17:10:46                0      nan
# 4    872611                  2022-10-25 17:10:46                0      nan
#
#    CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0            0            nan                nan                     NaT
# 1            0            nan                nan                     NaT
# 2            0            nan                nan                     NaT
# 3            0            nan                nan                     NaT
# 4            0            nan                nan                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN  \
# 0                     NaT  555862169  Sin Movimiento  2020-03-03 2024-06-17
# 1                     NaT  555862263  Sin Movimiento  2018-04-30 2021-04-05
# 2                     NaT  555862419  Sin Movimiento  2018-03-06 2021-03-02
# 3                     NaT  555862092  Sin Movimiento  2020-01-16 2020-07-16
# 4                     NaT  555862236  Sin Movimiento  2019-12-10 2021-10-04
#
#   MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
# 2    SOL         6200.00  0.35          0.35           2.17          2.11
# 3    SOL         1000.00  0.35          0.35           0.35          0.34
# 4    SOL        16800.00  0.35          0.35           5.88          5.71
#
#        NOMCOMPLETO  APEPATERNO  APEMATERNO FECNACIMIENTO  TIPDOCUMENTO  \
# 0          GABRIEL     SALINAS        LORA      19790130             2
# 1             JUAN  SANTILLANA   CALLIRGOS      19491019             2
# 2    JESUS EDUARDO       LOPEZ    FERREYRA      19920328             2
# 3           LESLIE      QUISPE  SANTIVA EZ      19970319             2
# 4  ARTURO FABRICIO     SALAZAR        LACA      19781022             2
#
#   NUMDOCUMENTO                     NOMBRE_DE_ARCHIVO  \
# 0     40227891  20100130204_0157001_20201122_100.TXT
# 1     09295733  20100130204_0157001_20201122_100.TXT
# 2     46923835  20100130204_0157001_20201122_100.TXT
# 3     60246361  20100130204_0157001_20201122_100.TXT
# 4     17457015  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001101062040002365100011010629960014659201P...  Error canal
# 1  901001101062940001863270011010626960011202701P...  Error canal
# 2  901001101096240003050550011010969960024944401P...  Error canal
# 3  901001101039840005891070011010397960026766001P...  Error canal
# 4  901001101062640002320000011010621960014102701P...  Error canal
#
#   CODIGO_ERROR           DESCRIPCION_ERROR FECHA_TRAMA         STATUS
# 0         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 1         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 2         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 3         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 4         1158  Trama repetida o duplicada  2020-11-22  Mes corriente

# %%
df_desgravamen[df_desgravamen['STATUS']=='Mes corriente'].head(6)
# Out:
#    NRO_LOTE LOTES_ANTERIORES         FECHA_CARGA  CODIGO_PRODUCTO PRODUCTO  \
# 0    872611                  2022-10-25 17:10:46                0      nan
# 1    872611                  2022-10-25 17:10:46                0      nan
# 2    872611                  2022-10-25 17:10:46                0      nan
# 3    872611                  2022-10-25 17:10:46                0      nan
# 4    872611                  2022-10-25 17:10:46                0      nan
# 5    872611                  2022-10-25 17:10:46                0      nan
#
#    CODIGO_PLAN NOMBRE_DE_PLAN COD_DE_CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0            0            nan                nan                     NaT
# 1            0            nan                nan                     NaT
# 2            0            nan                nan                     NaT
# 3            0            nan                nan                     NaT
# 4            0            nan                nan                     NaT
# 5            0            nan                nan                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO FEC__INICIO   FEC__FIN  \
# 0                     NaT  555862169  Sin Movimiento  2020-03-03 2024-06-17
# 1                     NaT  555862263  Sin Movimiento  2018-04-30 2021-04-05
# 2                     NaT  555862419  Sin Movimiento  2018-03-06 2021-03-02
# 3                     NaT  555862092  Sin Movimiento  2020-01-16 2020-07-16
# 4                     NaT  555862236  Sin Movimiento  2019-12-10 2021-10-04
# 5                     NaT  555861551  Sin Movimiento  2019-08-05 2020-08-05
#
#   MONEDA  SUMA_ASEGURADA  TASA  TASA_RECARGO  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL         5000.00  0.35          0.35           1.75          1.70
# 1    SOL        63892.89  0.35          0.35          22.36         21.71
# 2    SOL         6200.00  0.35          0.35           2.17          2.11
# 3    SOL         1000.00  0.35          0.35           0.35          0.34
# 4    SOL        16800.00  0.35          0.35           5.88          5.71
# 5    SOL         1000.00  0.35          0.35           0.35          0.34
#
#        NOMCOMPLETO  APEPATERNO  APEMATERNO FECNACIMIENTO  TIPDOCUMENTO  \
# 0          GABRIEL     SALINAS        LORA      19790130             2
# 1             JUAN  SANTILLANA   CALLIRGOS      19491019             2
# 2    JESUS EDUARDO       LOPEZ    FERREYRA      19920328             2
# 3           LESLIE      QUISPE  SANTIVA EZ      19970319             2
# 4  ARTURO FABRICIO     SALAZAR        LACA      19781022             2
# 5  YESSULY MINORKA      PAUCAR     USCACHI      19940208             2
#
#   NUMDOCUMENTO                     NOMBRE_DE_ARCHIVO  \
# 0     40227891  20100130204_0157001_20201122_100.TXT
# 1     09295733  20100130204_0157001_20201122_100.TXT
# 2     46923835  20100130204_0157001_20201122_100.TXT
# 3     60246361  20100130204_0157001_20201122_100.TXT
# 4     17457015  20100130204_0157001_20201122_100.TXT
# 5     73743507  20100130204_0157001_20201122_100.TXT
#
#                                          LINEA_TRAMA ORIGEN_ERROR  \
# 0  901001101062040002365100011010629960014659201P...  Error canal
# 1  901001101062940001863270011010626960011202701P...  Error canal
# 2  901001101096240003050550011010969960024944401P...  Error canal
# 3  901001101039840005891070011010397960026766001P...  Error canal
# 4  901001101062640002320000011010621960014102701P...  Error canal
# 5  901001100833640001640010011008330960003910501P...  Error canal
#
#   CODIGO_ERROR           DESCRIPCION_ERROR FECHA_TRAMA         STATUS
# 0         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 1         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 2         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 3         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 4         1158  Trama repetida o duplicada  2020-11-22  Mes corriente
# 5         1158  Trama repetida o duplicada  2020-11-22  Mes corriente

# %%
df_errores['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 1068    1
# 0003    1
# 1155    1
# 1150    1
# 1152    1
# 1116    1
# 0114    1
# 7578    1
# 0199    1
# 0011    1
# 2395    1
# 1137    1
# 0163    1
# 0177    1
# 1154    1
# 0155    1
# 1153    1
# 1157    1
# 0117    1
# 1151    1
# 9964    1
# 1608    1
# 0193    1
# 0039    1
# 0034    1
# 0050    1
# 0940    1
# 0035    1
# 1143    1
# 9963    1
# 1045    1
# 0010    1
# 9969    1
# 7460    1
# 9978    1
# 7440    1
# 0130    1
# 0757    1
# 0141    1
# 0317    1
# 0119    1
# 1140    1
# 0852    1
# 0061    1
# 1083    1
# 0022    1
# 0005    1
# 1195    1
# 1135    1
# 8023    1
# 1052    1
#         1
# 1136    1
# Name: count, dtype: int64

# %%
df_errores[df_errores['CODIGO_ERROR'].isna()].head(10)
# Out:
#    CODIGO_ERROR        DESCRIPCION_ERROR                DETALLE  \
# 11          NaN  ERROR EN CARGA DE TRAMA  NI Ãâ°XITO NI ERROR
#
#            SOLUCION SOLUCION_2
# 11  ANALISIS EMISOR

# %%
df_errores[df_errores['CODIGO_ERROR'].isin({'2395','7440'})].head()
# Out:
#    CODIGO_ERROR DESCRIPCION_ERROR                       DETALLE  \
# 10         2395     ERROR DE TASA                          TASA
# 42         7440        ERROR EDAD  EDAD - MANCOMUNO INEXISTENTE
#
#              SOLUCION          SOLUCION_2
# 10    ANALISIS EMISOR   CONFIGURACION SAS
# 42  CONFIGURACION SAS  REGLAS POR CAMBIAR

# %%
df_errores[df_errores['CODIGO_ERROR']==' '].head()
# Out:
#    CODIGO_ERROR     DESCRIPCION_ERROR               DETALLE         SOLUCION  \
# 62               SIN DETALLE DE ERROR  SIN DETALLE DE ERROR  ANALISIS EMISOR
#
#          SOLUCION_2
# 62  VOLVER A CARGAR

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR'].isna()].head(10)
# Out:
#     CODIGO_PRODUCTO LOTES_ANTERIORES    COD_DE_CERTIFICADO  \
# 12             3070                   00110727584000239265
# 13             3070                   00110252434000017945
# 14             3070                   00110781244000183779
# 26             3827                   00110130284010524337
# 27             3827                   00110130284010524337
# 28             3827                   00110130284010524337
# 29             3827                   00110130284010524337
# 42             3070                   00110252434000017945
# 43             3070                   00110252434000017945
# 44             3070                   00110252434000017945
#
#    FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO       IDEDET  \
# 12                     NaT                     NaT  289247736.0
# 13                     NaT                     NaT  289244884.0
# 14              2014-02-27              2027-02-28  289238827.0
# 26                     NaT                     NaT  295967400.0
# 27                     NaT                     NaT  295967400.0
# 28                     NaT                     NaT  295967400.0
# 29                     NaT                     NaT  295967400.0
# 42                     NaT                     NaT  313042743.0
# 43                     NaT                     NaT  313042743.0
# 44                     NaT                     NaT  313042743.0
#
#                                                 TRAMA TIPO_MOVIMIENTO  \
# 12  906001107275840002392650011048600020052715501U...      Renovacion
# 13  906001102524340000179450011025248020008135901P...      Renovacion
# 14  903001107812440001837790011014012020049982601P...      Renovacion
# 26  972001101302840105243370011013023969011141601P...       Inclusion
# 27  972001101302840105243370011013023969011141601P...       Inclusion
# 28  972001101302840105243370011013023969011141601P...       Inclusion
# 29  972001101302840105243370011013023969011141601P...       Inclusion
# 42  906001102524340000179450011025248020008135901P...      Renovacion
# 43  906001102524340000179450011025248020008135901P...      Renovacion
# 44  906001102524340000179450011025248020008135901P...      Renovacion
#
#    FEC__INICIO   FEC__FIN  ... SUMA_ASEGURADA  TASA  PRIMABRUTACAN  \
# 12  2019-03-29 2019-04-29  ...           0.00  0.00          22.77
# 13  2019-03-29 2019-04-29  ...           0.00  0.00          70.20
# 14  2019-03-11 2019-04-11  ...           0.00  0.00         191.80
# 26  2018-12-13 2021-01-02  ...       10378.68  0.48           0.00
# 27  2018-12-13 2021-01-02  ...       10378.68  0.48           0.00
# 28  2018-12-13 2021-01-02  ...       10378.68  0.48           0.00
# 29  2018-12-13 2021-01-02  ...       10378.68  0.48           0.00
# 42  2019-07-31 2019-08-31  ...           0.00  0.00          70.20
# 43  2019-07-31 2019-08-31  ...           0.00  0.00          70.20
# 44  2019-07-31 2019-08-31  ...           0.00  0.00          70.20
#
#     PRIMANETACAN                     NOMBRE_DE_ARCHIVO ORIGEN_ERROR  \
# 12         22.11  20100130204_0157001_20190404_002.TXT            0
# 13         68.16  20100130204_0157001_20190404_002.TXT            0
# 14        186.21  20100130204_0157001_20190404_002.TXT            0
# 26          0.00  20100130204_0157001_20190311_002.TXT    295967400
# 27          0.00  20100130204_0157001_20190311_002.TXT    295967400
# 28          0.00  20100130204_0157001_20190311_002.TXT    295967400
# 29          0.00  20100130204_0157001_20190311_002.TXT    295967400
# 42         68.16  20100130204_0157001_20190806_003.TXT    313042743
# 43         68.16  20100130204_0157001_20190806_003.TXT    313042743
# 44         68.16  20100130204_0157001_20190806_003.TXT    313042743
#
#      TIPO_ERROR CODIGO_ERROR FECHA_TRAMA         STATUS
# 12          NaN          NaN  2019-04-04  Mes corriente
# 13          NaN          NaN  2019-04-04  Mes corriente
# 14          NaN          NaN  2019-04-04  Mes corriente
# 26  Error Rimac          NaN  2019-03-11  Mes corriente
# 27  Error Rimac          NaN  2019-03-11  Mes corriente
# 28  Error Rimac          NaN  2019-03-11  Mes corriente
# 29  Error Rimac          NaN  2019-03-11  Mes corriente
# 42  Error Rimac          NaN  2019-08-06  Mes corriente
# 43  Error Rimac          NaN  2019-08-06  Mes corriente
# 44  Error Rimac          NaN  2019-08-06  Mes corriente
#
# [10 rows x 21 columns]

# %%
df_desgravamen[df_desgravamen['CODIGO_ERROR']==''].head()
# Out:
# Empty DataFrame
# Columns: [CODIGO_PRODUCTO, LOTES_ANTERIORES, COD_DE_CERTIFICADO, FECINI_ALTA_CERTIFICADO, FECFIN_ALTA_CERTIFICADO, IDEDET, TRAMA, TIPO_MOVIMIENTO, FEC__INICIO, FEC__FIN, MONEDA, SUMA_ASEGURADA, TASA, PRIMABRUTACAN, PRIMANETACAN, NOMBRE_DE_ARCHIVO, ORIGEN_ERROR, TIPO_ERROR, CODIGO_ERROR, FECHA_TRAMA, STATUS]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       53 non-null     object
#  1   DESCRIPCION_ERROR  54 non-null     object
#  2   DETALLE            54 non-null     object
#  3   SOLUCION           54 non-null     object
#  4   SOLUCION_2         54 non-null     object
# dtypes: object(5)
# memory usage: 2.5+ KB

# %%
df= df_desgravamen.merge(df_errores, on='CODIGO_ERROR', how='left')

# %%
df.head(3)
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES COD_DE_CERTIFICADO  \
# 0                0                                 NaN
# 1                0                                 NaN
# 2                0                                 NaN
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO       IDEDET  \
# 0                     NaT                     NaT  289236134.0
# 1                     NaT                     NaT  289235584.0
# 2                     NaT                     NaT  289239811.0
#
#                                                TRAMA TIPO_MOVIMIENTO  \
# 0  903001104868240007432580011048681020074429601U...  Sin Movimiento
# 1  903001104264440000623340011042641020015853501P...  Sin Movimiento
# 2  903001108315440008473680011012373020027799501P...  Sin Movimiento
#
#   FEC__INICIO   FEC__FIN  ...                     NOMBRE_DE_ARCHIVO  \
# 0  2019-03-15 2019-04-15  ...  20100130204_0157001_20190404_002.TXT
# 1  2019-03-01 2019-04-01  ...  20100130204_0157001_20190404_002.TXT
# 2  2019-03-01 2019-04-01  ...  20100130204_0157001_20190404_002.TXT
#
#    ORIGEN_ERROR   TIPO_ERROR  CODIGO_ERROR  FECHA_TRAMA         STATUS  \
# 0     289236134  Error canal          1155   2019-04-04  Mes corriente
# 1     289235584  Error canal          1155   2019-04-04  Mes corriente
# 2     289239811  Error canal          1155   2019-04-04  Mes corriente
#
#             DESCRIPCION_ERROR                     DETALLE           SOLUCION  \
# 0  TRAMA REPETIDA O DUPLICADA  TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
# 1  TRAMA REPETIDA O DUPLICADA  TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
# 2  TRAMA REPETIDA O DUPLICADA  TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION_2
# 0  ANULAR MASIVAS
# 1  ANULAR MASIVAS
# 2  ANULAR MASIVAS
#
# [3 rows x 25 columns]

# %%
df[df['CODIGO_ERROR'].isna()].head(10)
# Out:
#     CODIGO_PRODUCTO LOTES_ANTERIORES    COD_DE_CERTIFICADO  \
# 12             3070                   00110727584000239265
# 13             3070                   00110252434000017945
# 14             3070                   00110781244000183779
# 26             3827                   00110130284010524337
# 27             3827                   00110130284010524337
# 28             3827                   00110130284010524337
# 29             3827                   00110130284010524337
# 42             3070                   00110252434000017945
# 43             3070                   00110252434000017945
# 44             3070                   00110252434000017945
#
#    FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO       IDEDET  \
# 12                     NaT                     NaT  289247736.0
# 13                     NaT                     NaT  289244884.0
# 14              2014-02-27              2027-02-28  289238827.0
# 26                     NaT                     NaT  295967400.0
# 27                     NaT                     NaT  295967400.0
# 28                     NaT                     NaT  295967400.0
# 29                     NaT                     NaT  295967400.0
# 42                     NaT                     NaT  313042743.0
# 43                     NaT                     NaT  313042743.0
# 44                     NaT                     NaT  313042743.0
#
#                                                 TRAMA TIPO_MOVIMIENTO  \
# 12  906001107275840002392650011048600020052715501U...      Renovacion
# 13  906001102524340000179450011025248020008135901P...      Renovacion
# 14  903001107812440001837790011014012020049982601P...      Renovacion
# 26  972001101302840105243370011013023969011141601P...       Inclusion
# 27  972001101302840105243370011013023969011141601P...       Inclusion
# 28  972001101302840105243370011013023969011141601P...       Inclusion
# 29  972001101302840105243370011013023969011141601P...       Inclusion
# 42  906001102524340000179450011025248020008135901P...      Renovacion
# 43  906001102524340000179450011025248020008135901P...      Renovacion
# 44  906001102524340000179450011025248020008135901P...      Renovacion
#
#    FEC__INICIO   FEC__FIN  ...                     NOMBRE_DE_ARCHIVO  \
# 12  2019-03-29 2019-04-29  ...  20100130204_0157001_20190404_002.TXT
# 13  2019-03-29 2019-04-29  ...  20100130204_0157001_20190404_002.TXT
# 14  2019-03-11 2019-04-11  ...  20100130204_0157001_20190404_002.TXT
# 26  2018-12-13 2021-01-02  ...  20100130204_0157001_20190311_002.TXT
# 27  2018-12-13 2021-01-02  ...  20100130204_0157001_20190311_002.TXT
# 28  2018-12-13 2021-01-02  ...  20100130204_0157001_20190311_002.TXT
# 29  2018-12-13 2021-01-02  ...  20100130204_0157001_20190311_002.TXT
# 42  2019-07-31 2019-08-31  ...  20100130204_0157001_20190806_003.TXT
# 43  2019-07-31 2019-08-31  ...  20100130204_0157001_20190806_003.TXT
# 44  2019-07-31 2019-08-31  ...  20100130204_0157001_20190806_003.TXT
#
#     ORIGEN_ERROR   TIPO_ERROR  CODIGO_ERROR  FECHA_TRAMA         STATUS  \
# 12             0          NaN           NaN   2019-04-04  Mes corriente
# 13             0          NaN           NaN   2019-04-04  Mes corriente
# 14             0          NaN           NaN   2019-04-04  Mes corriente
# 26     295967400  Error Rimac           NaN   2019-03-11  Mes corriente
# 27     295967400  Error Rimac           NaN   2019-03-11  Mes corriente
# 28     295967400  Error Rimac           NaN   2019-03-11  Mes corriente
# 29     295967400  Error Rimac           NaN   2019-03-11  Mes corriente
# 42     313042743  Error Rimac           NaN   2019-08-06  Mes corriente
# 43     313042743  Error Rimac           NaN   2019-08-06  Mes corriente
# 44     313042743  Error Rimac           NaN   2019-08-06  Mes corriente
#
#           DESCRIPCION_ERROR             DETALLE         SOLUCION SOLUCION_2
# 12  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 13  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 14  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 26  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 27  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 28  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 29  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 42  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 43  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
# 44  ERROR EN CARGA DE TRAMA  NI ÃXITO NI ERROR  ANALISIS EMISOR
#
# [10 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42019 entries, 0 to 42018
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO_PRODUCTO          42019 non-null  int64
#  1   LOTES_ANTERIORES         42019 non-null  object
#  2   COD_DE_CERTIFICADO       6959 non-null   object
#  3   FECINI_ALTA_CERTIFICADO  2866 non-null   datetime64[ns]
#  4   FECFIN_ALTA_CERTIFICADO  2866 non-null   datetime64[ns]
#  5   IDEDET                   42007 non-null  float64
#  6   TRAMA                    42007 non-null  object
#  7   TIPO_MOVIMIENTO          42019 non-null  object
#  8   FEC__INICIO              41570 non-null  datetime64[ns]
#  9   FEC__FIN                 41544 non-null  datetime64[ns]
#  10  MONEDA                   42019 non-null  object
#  11  SUMA_ASEGURADA           42005 non-null  float64
#  12  TASA                     42019 non-null  float64
#  13  PRIMABRUTACAN            42005 non-null  float64
#  14  PRIMANETACAN             42019 non-null  float64
#  15  NOMBRE_DE_ARCHIVO        42007 non-null  object
#  16  ORIGEN_ERROR             42019 non-null  int64
#  17  TIPO_ERROR               41310 non-null  object
#  18  CODIGO_ERROR             40379 non-null  object
#  19  FECHA_TRAMA              42007 non-null  datetime64[ns]
#  20  STATUS                   42019 non-null  object
#  21  DESCRIPCION_ERROR        2541 non-null   object
#  22  DETALLE                  2541 non-null   object
#  23  SOLUCION                 2541 non-null   object
#  24  SOLUCION_2               2541 non-null   object
# dtypes: datetime64[ns](5), float64(5), int64(2), object(13)
# memory usage: 8.0+ MB
