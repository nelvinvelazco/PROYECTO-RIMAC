# %%
import pandas as pd
from datetime import datetime
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

# %%
df_errores= pd.read_csv('c:/data/tabla_errores.txt', sep='\t', encoding='latin1')
df_errores.head(3)
# Out:
#   CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1         0003                            ERROR EN CARGA DE TRAMA
# 2         1155                         TRAMA REPETIDA O DUPLICADA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
# 2                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION 2
# 0  ANULAR MASIVAS
# 1             NaN
# 2  ANULAR MASIVAS

# %%
df_errores= df_errores.dropna(subset=['CODIGO_ERROR']) # Elimina filas con CODIGO_ERROR nulo

# %%
df_errores= df_errores.rename(columns={'SOLUCION 2': 'SOLUCION_2'}) # cambiar nombre de las columnas
df_errores= df_errores.fillna({'SOLUCION_2':''})

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       55 non-null     object
#  1   DESCRIPCION_ERROR  55 non-null     object
#  2   DETALLE            55 non-null     object
#  3   SOLUCION           55 non-null     object
#  4   SOLUCION_2         55 non-null     object
# dtypes: object(5)
# memory usage: 2.6+ KB

# %%
# Se carga el dataset en excel de Accidentes mortales
df_desgravamen= pd.read_excel('C:/data/446 - Desgravamen Desempleo - BBVA - P1.xlsx', sheet_name='Hoja1')

# %%
df_desgravamen.columns = (
    df_desgravamen.columns
    .str.strip()  # quitar espacios al inicio/fin
    .str.upper()  # opcional: todo en mayúsculas
    .str.replace(r'[^A-Za-z0-9_]', '_', regex=True)  # reemplazar todo lo que no sea letra/número/_ por _
)

# %%
df_desgravamen= df_desgravamen.rename(columns={'CODIGO_ERROR': 'TIPO_ERROR','DESCRIPCION_ERROR': 'CODIGO_ERROR'}) # cambiar nombre de las columnas

# %%
df_desgravamen= df_desgravamen[['CODIGO_PRODUCTO', 'LOTES_ANTERIORES','COD_DE_CERTIFICADO', 'FECINI_ALTA_CERTIFICADO', 
                                'FECFIN_ALTA_CERTIFICADO','IDEDET', 'TIPO_MOVIMIENTO', 'FEC__INICIO', 'FEC__FIN', 'MONEDA', 
                                'SUMA_ASEGURADA', 'TASA', 'PRIMABRUTACAN', 'PRIMANETACAN', 'NOMBRE_DE_ARCHIVO', 
                                'ORIGEN_ERROR', 'TIPO_ERROR', 'CODIGO_ERROR']]

# %%
df_desgravamen.head(3)  # Displaying the first five rows of the DataFrame
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 0           3070.0      41924|41960        1.102912e+17
# 1           3070.0      41924|41960        1.102771e+17
# 2           3070.0      41924|41960        1.103549e+17
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO    IDEDET TIPO_MOVIMIENTO  \
# 0                     NaN                     NaN  76792662      Renovacion
# 1                     NaN                     NaN  76792295      Renovacion
# 2                     NaN                     NaN  76795338      Renovacion
#
#            FEC__INICIO             FEC__FIN MONEDA SUMA_ASEGURADA TASA  \
# 0  2015-03-26 00:00:00  2015-04-26 00:00:00    SOL              0    0
# 1  2015-03-20 00:00:00  2015-04-20 00:00:00    SOL              0    0
# 2  2015-03-12 00:00:00  2015-04-12 00:00:00    SOL              0    0
#
#   PRIMABRUTACAN  PRIMANETACAN                           NOMBRE_DE_ARCHIVO  \
# 0          1.53          1.49  20100130204_0157001_20150409_001_41924.TXT
# 1         13.13         12.75  20100130204_0157001_20150409_001_41924.TXT
# 2          6.23          6.05  20100130204_0157001_20150409_001_41924.TXT
#
#    ORIGEN_ERROR   TIPO_ERROR  CODIGO_ERROR
# 0    76792662.0  Error canal        1150.0
# 1    76792295.0  Error canal        1150.0
# 2    76795338.0  Error canal        1150.0

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO_PRODUCTO          48852 non-null  float64
#  1   LOTES_ANTERIORES         91 non-null     object
#  2   COD_DE_CERTIFICADO       48852 non-null  float64
#  3   FECINI_ALTA_CERTIFICADO  33562 non-null  object
#  4   FECFIN_ALTA_CERTIFICADO  33562 non-null  object
#  5   IDEDET                   50659 non-null  int64
#  6   TIPO_MOVIMIENTO          50659 non-null  object
#  7   FEC__INICIO              50658 non-null  object
#  8   FEC__FIN                 50658 non-null  object
#  9   MONEDA                   50658 non-null  object
#  10  SUMA_ASEGURADA           50659 non-null  object
#  11  TASA                     50659 non-null  object
#  12  PRIMABRUTACAN            50659 non-null  object
#  13  PRIMANETACAN             50659 non-null  float64
#  14  NOMBRE_DE_ARCHIVO        50659 non-null  object
#  15  ORIGEN_ERROR             28833 non-null  float64
#  16  TIPO_ERROR               28833 non-null  object
#  17  CODIGO_ERROR             26946 non-null  float64
# dtypes: float64(5), int64(1), object(12)
# memory usage: 7.0+ MB

# %%
df_desgravamen[df_desgravamen['CODIGO_PRODUCTO'].isnull()].head()
# Out:
#     CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 7               NaN              NaN                 NaN
# 9               NaN              NaN                 NaN
# 21              NaN              NaN                 NaN
# 22              NaN              NaN                 NaN
# 23              NaN              NaN                 NaN
#
#    FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 7                      NaN                     NaN  142337287  Sin Movimiento
# 9                      NaN                     NaN  142268938  Sin Movimiento
# 21                     NaN                     NaN  132976876  Sin Movimiento
# 22                     NaN                     NaN  132976877  Sin Movimiento
# 23                     NaN                     NaN  132976878  Sin Movimiento
#
#             FEC__INICIO             FEC__FIN MONEDA SUMA_ASEGURADA  TASA  \
# 7   2016-06-30 00:00:00  2016-07-31 00:00:00    SOL              0     0
# 9   2016-06-30 00:00:00  2016-07-31 00:00:00    SOL              0     0
# 21  2010-07-20 00:00:00  2015-07-02 00:00:00    SOL       54032.75  0.27
# 22  2016-03-31 00:00:00  2031-03-31 00:00:00    USD         300000  0.52
# 23  2016-03-31 00:00:00  2031-03-31 00:00:00    USD         300000  0.52
#
#    PRIMABRUTACAN  PRIMANETACAN                     NOMBRE_DE_ARCHIVO  \
# 7         330.67        321.04  20100130204_0157001_20160706_002.TXT
# 9          57.96         56.27  20100130204_0157001_20160706_002.TXT
# 21         14.59         14.17  20100130204_0157001_20160519_005.TXT
# 22           156        151.46  20100130204_0157001_20160519_005.TXT
# 23           156        151.46  20100130204_0157001_20160519_005.TXT
#
#     ORIGEN_ERROR   TIPO_ERROR  CODIGO_ERROR
# 7    142337287.0  Error canal        1155.0
# 9    142268938.0  Error canal        1155.0
# 21   132976876.0  Error canal        1155.0
# 22   132976877.0  Error canal         193.0
# 23   132976878.0  Error canal        1155.0

# %%
df_desgravamen= df_desgravamen.fillna({'LOTES_ANTERIORES':'', 'SUMA_ASEGURADA':0, 'TASA':0, 'PRIMABRUTACAN':0, 'PRIMANETACAN':0,
                                       'MONEDA': 'SIN DATO'})

# %%
df_desgravamen['COD_DE_CERTIFICADO'] = df_desgravamen['COD_DE_CERTIFICADO'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
df_desgravamen['CODIGO_PRODUCTO'] = df_desgravamen['CODIGO_PRODUCTO'].fillna(0).astype('int')
df_desgravamen["LOTES_ANTERIORES"] = df_desgravamen["LOTES_ANTERIORES"].astype(str)
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['TIPO_MOVIMIENTO'] = df_desgravamen['TIPO_MOVIMIENTO'].astype(str)
df_desgravamen['FEC__INICIO'] = pd.to_datetime(df_desgravamen['FEC__INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC__FIN'] = pd.to_datetime(df_desgravamen['FEC__FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['SUMA_ASEGURADA']= pd.to_numeric(df_desgravamen['SUMA_ASEGURADA'], errors='coerce')
df_desgravamen['TASA']= pd.to_numeric(df_desgravamen['TASA'], errors='coerce')
df_desgravamen['PRIMABRUTACAN']= pd.to_numeric(df_desgravamen['PRIMABRUTACAN'], errors='coerce')
df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
df_desgravamen['ORIGEN_ERROR'] = df_desgravamen['ORIGEN_ERROR'].fillna(0).astype('int')
df_desgravamen['CODIGO_ERROR'] = df_desgravamen['CODIGO_ERROR'].fillna(0).astype('int')

# %%
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].replace('nan', 'SIN DATO')

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO_PRODUCTO          50659 non-null  int64
#  1   LOTES_ANTERIORES         50659 non-null  object
#  2   COD_DE_CERTIFICADO       50659 non-null  object
#  3   FECINI_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  4   FECFIN_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  5   IDEDET                   50659 non-null  int64
#  6   TIPO_MOVIMIENTO          50659 non-null  object
#  7   FEC__INICIO              50142 non-null  datetime64[ns]
#  8   FEC__FIN                 50142 non-null  datetime64[ns]
#  9   MONEDA                   50659 non-null  object
#  10  SUMA_ASEGURADA           50146 non-null  float64
#  11  TASA                     50657 non-null  float64
#  12  PRIMABRUTACAN            50151 non-null  float64
#  13  PRIMANETACAN             50659 non-null  float64
#  14  NOMBRE_DE_ARCHIVO        50659 non-null  object
#  15  ORIGEN_ERROR             50659 non-null  int64
#  16  TIPO_ERROR               28833 non-null  object
#  17  CODIGO_ERROR             50659 non-null  int64
# dtypes: datetime64[ns](4), float64(4), int64(4), object(6)
# memory usage: 7.0+ MB

# %%
df_desgravamen.head(5)
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 0             3070      41924|41960  110291214000143008
# 1             3070      41924|41960  110277104000246000
# 2             3070      41924|41960  110354884000092000
# 3             3070      41924|41960  110195594000396992
# 4             3827                   110960264000002000
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0                     NaT                     NaT   76792662      Renovacion
# 1                     NaT                     NaT   76792295      Renovacion
# 2                     NaT                     NaT   76795338      Renovacion
# 3                     NaT                     NaT   76787274      Renovacion
# 4                     NaT                     NaT  142143999      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  PRIMABRUTACAN  \
# 0  2015-03-26 2015-04-26    SOL             0.0   0.0           1.53
# 1  2015-03-20 2015-04-20    SOL             0.0   0.0          13.13
# 2  2015-03-12 2015-04-12    SOL             0.0   0.0           6.23
# 3  2015-03-18 2015-04-18    SOL             0.0   0.0           0.44
# 4  2016-06-06 2016-07-06    USD             0.0   0.0           8.99
#
#    PRIMANETACAN                           NOMBRE_DE_ARCHIVO  ORIGEN_ERROR  \
# 0          1.49  20100130204_0157001_20150409_001_41924.TXT      76792662
# 1         12.75  20100130204_0157001_20150409_001_41924.TXT      76792295
# 2          6.05  20100130204_0157001_20150409_001_41924.TXT      76795338
# 3          0.43  20100130204_0157001_20150409_001_41924.TXT      76787274
# 4          8.73        20100130204_0157001_20160706_002.TXT     142143999
#
#     TIPO_ERROR  CODIGO_ERROR
# 0  Error canal          1150
# 1  Error canal          1150
# 2  Error canal          1150
# 3  Error canal          1150
# 4  Error canal          1152

# %%
df_desgravamen[df_desgravamen['FECINI_ALTA_CERTIFICADO'].isnull()]['FECINI_ALTA_CERTIFICADO'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#TIPO MOVIMIENTO
df_desgravamen['FECINI_ALTA_CERTIFICADO'].value_counts()  # Counting occurrences of each unique value in the 'TIPO MOVIMIENTO' column
# Out:
# FECINI_ALTA_CERTIFICADO
# 2015-03-31    134
# 2014-12-30    124
# 2015-05-29    114
# 2015-10-30    106
# 2015-07-31    105
#              ...
# 2012-08-23      1
# 2013-01-08      1
# 2013-05-08      1
# 2013-03-11      1
# 2017-01-15      1
# Name: count, Length: 1161, dtype: int64

# %%
#MONEDA
df_desgravamen['MONEDA'].value_counts()  # Counting occurrences of each unique value in the 'MONEDA' column
# Out:
# MONEDA
# SOL         46356
# USD          4302
# SIN DATO        1
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['MONEDA']=='SIN DATO'].head()
# Out:
#        CODIGO_PRODUCTO LOTES_ANTERIORES COD_DE_CERTIFICADO  \
# 46033                0                                   0
#
#       FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET  \
# 46033                     NaT                     NaT  132857441
#
#       TIPO_MOVIMIENTO FEC__INICIO FEC__FIN    MONEDA  SUMA_ASEGURADA  TASA  \
# 46033  Sin Movimiento         NaT      NaT  SIN DATO             0.0   0.0
#
#        PRIMABRUTACAN  PRIMANETACAN                     NOMBRE_DE_ARCHIVO  \
# 46033            0.0           0.0  20100130204_0157001_20160511_001.TXT
#
#        ORIGEN_ERROR   TIPO_ERROR  CODIGO_ERROR
# 46033     132857441  Error canal           193

# %%
def extraer_fecha(fecha):
    try:
        fecha_str = fecha.split("_")[2]
        return datetime.strptime(fecha_str, "%Y%m%d").date()
    except Exception:
        return None  # En caso de error

# %%
# Aplicar a la columna
df_desgravamen['FECHA_TRAMA'] = df_desgravamen['NOMBRE_DE_ARCHIVO'].apply(extraer_fecha)

# %%
df_desgravamen['FECHA_TRAMA']= pd.to_datetime(df_desgravamen['FECHA_TRAMA'], errors='coerce')

# %%
def clasificar(row):
    # Si lote no es nulo
    if str(row['LOTES_ANTERIORES']).strip() != "":
        return 'Regularizacion'
    
    # Si último número del nombre de archivo > 100
    try:
        ultimo_numero = int(row['NOMBRE_DE_ARCHIVO'].split("_")[-1][:-4])
        if ultimo_numero > 100:
            return 'Regularizacion'
    except:
        pass
    
    # Si ninguna condición se cumple
    return 'Mes corriente'

# %%
nombre = '20100130204_0157001_20150409_001_41924.TXT'
numero= int(nombre.split("_")[-1][:-4])
print(numero)
# Out:
# 41924

# %%
#df_desgravamen['REGULARIZACION']= df_desgravamen['LOTES ANTERIORES'].notnull()
df_desgravamen['STATUS']= df_desgravamen.apply(clasificar, axis=1)

# %%
df_desgravamen['STATUS'].value_counts()
# Out:
# STATUS
# Mes corriente     50541
# Regularizacion      118
# Name: count, dtype: int64

# %%
df_desgravamen.head(6)
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 0             3070      41924|41960  110291214000143008
# 1             3070      41924|41960  110277104000246000
# 2             3070      41924|41960  110354884000092000
# 3             3070      41924|41960  110195594000396992
# 4             3827                   110960264000002000
# 5             3827                   110554314000032992
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0                     NaT                     NaT   76792662      Renovacion
# 1                     NaT                     NaT   76792295      Renovacion
# 2                     NaT                     NaT   76795338      Renovacion
# 3                     NaT                     NaT   76787274      Renovacion
# 4                     NaT                     NaT  142143999      Renovacion
# 5                     NaT                     NaT  142049999      Renovacion
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  PRIMABRUTACAN  \
# 0  2015-03-26 2015-04-26    SOL             0.0   0.0           1.53
# 1  2015-03-20 2015-04-20    SOL             0.0   0.0          13.13
# 2  2015-03-12 2015-04-12    SOL             0.0   0.0           6.23
# 3  2015-03-18 2015-04-18    SOL             0.0   0.0           0.44
# 4  2016-06-06 2016-07-06    USD             0.0   0.0           8.99
# 5  2016-06-10 2016-07-10    SOL             0.0   0.0         183.03
#
#    PRIMANETACAN                           NOMBRE_DE_ARCHIVO  ORIGEN_ERROR  \
# 0          1.49  20100130204_0157001_20150409_001_41924.TXT      76792662
# 1         12.75  20100130204_0157001_20150409_001_41924.TXT      76792295
# 2          6.05  20100130204_0157001_20150409_001_41924.TXT      76795338
# 3          0.43  20100130204_0157001_20150409_001_41924.TXT      76787274
# 4          8.73        20100130204_0157001_20160706_002.TXT     142143999
# 5        177.70        20100130204_0157001_20160706_002.TXT     142049999
#
#     TIPO_ERROR  CODIGO_ERROR FECHA_TRAMA          STATUS
# 0  Error canal          1150  2015-04-09  Regularizacion
# 1  Error canal          1150  2015-04-09  Regularizacion
# 2  Error canal          1150  2015-04-09  Regularizacion
# 3  Error canal          1150  2015-04-09  Regularizacion
# 4  Error canal          1152  2016-07-06   Mes corriente
# 5  Error canal          1152  2016-07-06   Mes corriente

# %%
df_desgravamen[df_desgravamen['STATUS']=='Mes corriente'].head(6)
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 4             3827                   110960264000002000
# 5             3827                   110554314000032992
# 6             3827                   110285464000440992
# 7                0                                    0
# 8             3827                   110358914000162000
# 9                0                                    0
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 4                     NaT                     NaT  142143999      Renovacion
# 5                     NaT                     NaT  142049999      Renovacion
# 6                     NaT                     NaT  141890380      Renovacion
# 7                     NaT                     NaT  142337287  Sin Movimiento
# 8              2016-03-18              2016-06-18  142328819      Renovacion
# 9                     NaT                     NaT  142268938  Sin Movimiento
#
#   FEC__INICIO   FEC__FIN MONEDA  SUMA_ASEGURADA  TASA  PRIMABRUTACAN  \
# 4  2016-06-06 2016-07-06    USD             0.0   0.0           8.99
# 5  2016-06-10 2016-07-10    SOL             0.0   0.0         183.03
# 6  2016-06-30 2016-07-31    USD             0.0   0.0          29.07
# 7  2016-06-30 2016-07-31    SOL             0.0   0.0         330.67
# 8  2016-06-20 2016-07-20    SOL             0.0   0.0         490.04
# 9  2016-06-30 2016-07-31    SOL             0.0   0.0          57.96
#
#    PRIMANETACAN                     NOMBRE_DE_ARCHIVO  ORIGEN_ERROR  \
# 4          8.73  20100130204_0157001_20160706_002.TXT     142143999
# 5        177.70  20100130204_0157001_20160706_002.TXT     142049999
# 6         28.22  20100130204_0157001_20160706_002.TXT     141890380
# 7        321.04  20100130204_0157001_20160706_002.TXT     142337287
# 8        475.77  20100130204_0157001_20160706_002.TXT     142328819
# 9         56.27  20100130204_0157001_20160706_002.TXT     142268938
#
#     TIPO_ERROR  CODIGO_ERROR FECHA_TRAMA         STATUS
# 4  Error canal          1152  2016-07-06  Mes corriente
# 5  Error canal          1152  2016-07-06  Mes corriente
# 6  Error canal          1152  2016-07-06  Mes corriente
# 7  Error canal          1155  2016-07-06  Mes corriente
# 8  Error canal          1140  2016-07-06  Mes corriente
# 9  Error canal          1155  2016-07-06  Mes corriente

# %%
df_errores['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 2395    2
# 7440    2
# 0003    1
# 1150    1
# 1155    1
# 1152    1
# 1116    1
# 7578    1
# 0114    1
# 0199    1
# 0011    1
# 1137    1
# 0163    1
# 0177    1
# 1154    1
# 0155    1
# 1153    1
# 1157    1
# 0117    1
# 1151    1
# 1068    1
# 9964    1
# 1608    1
# 0039    1
# 0193    1
# 0050    1
# 0940    1
# 0035    1
# 0034    1
# 1143    1
# 9963    1
# 0010    1
# 1045    1
# 9969    1
# 7460    1
# 9978    1
# 0130    1
# 0757    1
# 0141    1
# 0317    1
# 0119    1
# 1140    1
# 0852    1
# 0061    1
# 1083    1
# 0022    1
# 0005    1
# 1195    1
# 1135    1
# 8023    1
# 1052    1
#         1
# 1136    1
# Name: count, dtype: int64

# %%
df_errores[df_errores['CODIGO_ERROR'].isin({'2395','7440'})].head()
# Out:
#    CODIGO_ERROR DESCRIPCION_ERROR                        DETALLE  \
# 10         2395     ERROR DE TASA                           TASA
# 23         2395     ERROR DE TASA  TASA (EN BLANCO) (PROD VIEJO)
# 42         7440        ERROR EDAD   EDAD - MANCOMUNO INEXISTENTE
# 44         7440        ERROR EDAD               EDAD - MANCOMUNO
#
#              SOLUCION          SOLUCION_2
# 10    ANALISIS EMISOR   CONFIGURACION SAS
# 23    ANALISIS EMISOR   CONFIGURACION SAS
# 42  CONFIGURACION SAS  REGLAS POR CAMBIAR
# 44  CONFIGURACION SAS  REGLAS POR CAMBIAR

# %%
df_errores= df_errores.drop_duplicates(subset=['CODIGO_ERROR'])

# %%
df_errores[df_errores['CODIGO_ERROR'].isin({'2395','7440'})].head()
# Out:
#    CODIGO_ERROR DESCRIPCION_ERROR                       DETALLE  \
# 10         2395     ERROR DE TASA                          TASA
# 42         7440        ERROR EDAD  EDAD - MANCOMUNO INEXISTENTE
#
#              SOLUCION          SOLUCION_2
# 10    ANALISIS EMISOR   CONFIGURACION SAS
# 42  CONFIGURACION SAS  REGLAS POR CAMBIAR

# %%
df_errores[df_errores['CODIGO_ERROR']==' '].head()
# Out:
#    CODIGO_ERROR     DESCRIPCION_ERROR               DETALLE         SOLUCION  \
# 62               SIN DETALLE DE ERROR  SIN DETALLE DE ERROR  ANALISIS EMISOR
#
#          SOLUCION_2
# 62  VOLVER A CARGAR

# %%
df_errores[df_errores['CODIGO_ERROR']==' '] = 0

# %%
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       53 non-null     object
#  1   DESCRIPCION_ERROR  53 non-null     object
#  2   DETALLE            53 non-null     object
#  3   SOLUCION           53 non-null     object
#  4   SOLUCION_2         53 non-null     object
# dtypes: object(5)
# memory usage: 2.5+ KB

# %%
df_errores['CODIGO_ERROR']= df_errores['CODIGO_ERROR'].astype('int')

# %%
df= df_desgravamen.merge(df_errores, on='CODIGO_ERROR', how='left')

# %%
df.head(10)
# Out:
#    CODIGO_PRODUCTO LOTES_ANTERIORES  COD_DE_CERTIFICADO  \
# 0             3070      41924|41960  110291214000143008
# 1             3070      41924|41960  110277104000246000
# 2             3070      41924|41960  110354884000092000
# 3             3070      41924|41960  110195594000396992
# 4             3827                   110960264000002000
# 5             3827                   110554314000032992
# 6             3827                   110285464000440992
# 7                0                                    0
# 8             3827                   110358914000162000
# 9                0                                    0
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO     IDEDET TIPO_MOVIMIENTO  \
# 0                     NaT                     NaT   76792662      Renovacion
# 1                     NaT                     NaT   76792295      Renovacion
# 2                     NaT                     NaT   76795338      Renovacion
# 3                     NaT                     NaT   76787274      Renovacion
# 4                     NaT                     NaT  142143999      Renovacion
# 5                     NaT                     NaT  142049999      Renovacion
# 6                     NaT                     NaT  141890380      Renovacion
# 7                     NaT                     NaT  142337287  Sin Movimiento
# 8              2016-03-18              2016-06-18  142328819      Renovacion
# 9                     NaT                     NaT  142268938  Sin Movimiento
#
#   FEC__INICIO   FEC__FIN MONEDA  ...  \
# 0  2015-03-26 2015-04-26    SOL  ...
# 1  2015-03-20 2015-04-20    SOL  ...
# 2  2015-03-12 2015-04-12    SOL  ...
# 3  2015-03-18 2015-04-18    SOL  ...
# 4  2016-06-06 2016-07-06    USD  ...
# 5  2016-06-10 2016-07-10    SOL  ...
# 6  2016-06-30 2016-07-31    USD  ...
# 7  2016-06-30 2016-07-31    SOL  ...
# 8  2016-06-20 2016-07-20    SOL  ...
# 9  2016-06-30 2016-07-31    SOL  ...
#
#                             NOMBRE_DE_ARCHIVO  ORIGEN_ERROR   TIPO_ERROR  \
# 0  20100130204_0157001_20150409_001_41924.TXT      76792662  Error canal
# 1  20100130204_0157001_20150409_001_41924.TXT      76792295  Error canal
# 2  20100130204_0157001_20150409_001_41924.TXT      76795338  Error canal
# 3  20100130204_0157001_20150409_001_41924.TXT      76787274  Error canal
# 4        20100130204_0157001_20160706_002.TXT     142143999  Error canal
# 5        20100130204_0157001_20160706_002.TXT     142049999  Error canal
# 6        20100130204_0157001_20160706_002.TXT     141890380  Error canal
# 7        20100130204_0157001_20160706_002.TXT     142337287  Error canal
# 8        20100130204_0157001_20160706_002.TXT     142328819  Error canal
# 9        20100130204_0157001_20160706_002.TXT     142268938  Error canal
#
#    CODIGO_ERROR FECHA_TRAMA          STATUS           DESCRIPCION_ERROR  \
# 0          1150  2015-04-09  Regularizacion               ERROR EN ALTA
# 1          1150  2015-04-09  Regularizacion               ERROR EN ALTA
# 2          1150  2015-04-09  Regularizacion               ERROR EN ALTA
# 3          1150  2015-04-09  Regularizacion               ERROR EN ALTA
# 4          1152  2016-07-06   Mes corriente               ERROR EN ALTA
# 5          1152  2016-07-06   Mes corriente               ERROR EN ALTA
# 6          1152  2016-07-06   Mes corriente               ERROR EN ALTA
# 7          1155  2016-07-06   Mes corriente  TRAMA REPETIDA O DUPLICADA
# 8          1140  2016-07-06   Mes corriente              ERROR VIGENCIA
# 9          1155  2016-07-06   Mes corriente  TRAMA REPETIDA O DUPLICADA
#
#                                              DETALLE           SOLUCION  \
# 0  EL ALTA DEL NRO. CERTIFICADO EXTERNO SE ENCUEN...    ANALISIS EMISOR
# 1  EL ALTA DEL NRO. CERTIFICADO EXTERNO SE ENCUEN...    ANALISIS EMISOR
# 2  EL ALTA DEL NRO. CERTIFICADO EXTERNO SE ENCUEN...    ANALISIS EMISOR
# 3  EL ALTA DEL NRO. CERTIFICADO EXTERNO SE ENCUEN...    ANALISIS EMISOR
# 4  NO EXISTE ALTA PARA EL CERTIFICADO O TIENE BAJ...    ANALISIS EMISOR
# 5  NO EXISTE ALTA PARA EL CERTIFICADO O TIENE BAJ...    ANALISIS EMISOR
# 6  NO EXISTE ALTA PARA EL CERTIFICADO O TIENE BAJ...    ANALISIS EMISOR
# 7                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
# 8                                     ERROR VIGENCIA    ANALISIS EMISOR
# 9                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
#
#        SOLUCION_2
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7  ANULAR MASIVAS
# 8
# 9  ANULAR MASIVAS
#
# [10 rows x 24 columns]
