# %%
import pandas as pd

# %%
df_errores= pd.read_csv('C:/data/tabla_errores.txt', sep='\t', encoding='latin1')
df_errores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_ERROR       55 non-null     object
#  1   DESCRIPCION_ERROR  64 non-null     object
#  2   DETALLE            63 non-null     object
#  3   SOLUCION           64 non-null     object
#  4   SOLUCION 2         22 non-null     object
# dtypes: object(5)
# memory usage: 2.6+ KB

# %%
# Se carga el dataset en excel de Accidentes mortales
df_desgravamen= pd.read_excel('C:/data/446 - Desgravamen Desempleo - BBVA - P1.xlsx', sheet_name='Hoja1')
# Out:
# c:\Users\Nelvin Velazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell X28398 is marked as a date but the serial value 19900831 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Nelvin Velazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell X28399 is marked as a date but the serial value 19821005 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Nelvin Velazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell X28400 is marked as a date but the serial value 19740903 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# ...

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NRO LOTE                 50659 non-null  int64
#  1   LOTES ANTERIORES         91 non-null     object
#  2   FECHA CARGA              50659 non-null  object
#  3   CODIGO PRODUCTO          48852 non-null  float64
#  4   PRODUCTO                 48852 non-null  object
#  5   CODIGO PLAN              48852 non-null  float64
#  6   NOMBRE DE PLAN           48852 non-null  object
#  7   COD DE CERTIFICADO       48852 non-null  float64
#  8   FECINI_ALTA_CERTIFICADO  33562 non-null  object
#  9   FECFIN_ALTA_CERTIFICADO  33562 non-null  object
#  10  IDEDET                   50659 non-null  int64
#  11  TIPO MOVIMIENTO          50659 non-null  object
#  12  FEC. INICIO              50658 non-null  object
#  13  FEC. FIN                 50658 non-null  object
# ...

# %%
df_desgravamen= df_desgravamen[['LOTES ANTERIORES','CODIGO PRODUCTO', 'COD DE CERTIFICADO', 'FECINI_ALTA_CERTIFICADO', 
                                'FECFIN_ALTA_CERTIFICADO','IDEDET', 'TIPO MOVIMIENTO', 'FEC. INICIO', 'FEC. FIN', 'MONEDA', 
                                'SUMA ASEGURADA', 'TASA', 'PRIMABRUTACAN', 'PRIMANETACAN', 'NOMBRE DE ARCHIVO', 
                                'ORIGEN ERROR', 'CODIGO ERROR', 'DESCRIPCION ERROR']]

# %%
df_desgravamen.head(3)  # Displaying the first five rows of the DataFrame
# Out:
#   LOTES ANTERIORES  CODIGO PRODUCTO  COD DE CERTIFICADO  \
# 0      41924|41960           3070.0        1.102912e+17
# 1      41924|41960           3070.0        1.102771e+17
# 2      41924|41960           3070.0        1.103549e+17
#
#   FECINI_ALTA_CERTIFICADO FECFIN_ALTA_CERTIFICADO    IDEDET TIPO MOVIMIENTO  \
# 0                     NaN                     NaN  76792662      Renovacion
# 1                     NaN                     NaN  76792295      Renovacion
# 2                     NaN                     NaN  76795338      Renovacion
#
#            FEC. INICIO             FEC. FIN MONEDA SUMA ASEGURADA TASA  \
# 0  2015-03-26 00:00:00  2015-04-26 00:00:00    SOL              0    0
# 1  2015-03-20 00:00:00  2015-04-20 00:00:00    SOL              0    0
# 2  2015-03-12 00:00:00  2015-04-12 00:00:00    SOL              0    0
#
#   PRIMABRUTACAN  PRIMANETACAN                           NOMBRE DE ARCHIVO  \
# ...

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LOTES ANTERIORES         91 non-null     object
#  1   CODIGO PRODUCTO          48852 non-null  float64
#  2   COD DE CERTIFICADO       48852 non-null  float64
#  3   FECINI_ALTA_CERTIFICADO  33562 non-null  object
#  4   FECFIN_ALTA_CERTIFICADO  33562 non-null  object
#  5   IDEDET                   50659 non-null  int64
#  6   TIPO MOVIMIENTO          50659 non-null  object
#  7   FEC. INICIO              50658 non-null  object
#  8   FEC. FIN                 50658 non-null  object
#  9   MONEDA                   50658 non-null  object
#  10  SUMA ASEGURADA           50659 non-null  object
#  11  TASA                     50659 non-null  object
#  12  PRIMABRUTACAN            50659 non-null  object
#  13  PRIMANETACAN             50659 non-null  float64
# ...

# %%
df_desgravamen['IDELOTE'].value_counts()
# Out:
# IDELOTE
# 901001101476440002327130011014765960019828601PEN2LOMA                          LLANOS                        JUAN LORENZO                  MS19881107L45401826  MONTEVIDEO                                                                                                                        883     24      CERCADO DE LIMA               01L0001PERMJR.   010010019812751201502102015021020150511000C00000000500000{000000000001750 06I1 00035000000000000000000000000000000000000001750                                                                                                                                                                02    8
# ...

# %%
def limpiar_codigo_error(x):
    if pd.isnull(x):
        return ''
    try:
        # Si es un número tipo float, conviértelo a int y luego a str
        return str(int(x))
    except:
        # Si no se puede convertir, déjalo como str tal cual
        return str(x)

# %%
df_desgravamen['CODIGO ERROR'] = df_desgravamen['CODIGO ERROR'].apply(limpiar_codigo_error)

# %%
df_desgravamen['CODIGO ERROR'].value_counts()
# Out:
# CODIGO ERROR
#                21826
# Error canal    15461
# Error Rimac    13372
# Name: count, dtype: int64

# %%
df_desgravamen['COD DE CERTIFICADO'] = df_desgravamen['COD DE CERTIFICADO'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
df_desgravamen['FECINI_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECINI_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['FECFIN_ALTA_CERTIFICADO'] = pd.to_datetime(df_desgravamen['FECFIN_ALTA_CERTIFICADO'], errors='coerce')
df_desgravamen['TIPO MOVIMIENTO'] = df_desgravamen['TIPO MOVIMIENTO'].astype(str)
df_desgravamen['FEC. INICIO'] = pd.to_datetime(df_desgravamen['FEC. INICIO'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['FEC. FIN'] = pd.to_datetime(df_desgravamen['FEC. FIN'], format='%d/%m/%Y', errors='coerce')
df_desgravamen['MONEDA'] = df_desgravamen['MONEDA'].astype(str)
df_desgravamen['SUMA ASEGURADA']= pd.to_numeric(df_desgravamen['SUMA ASEGURADA'], errors='coerce')
df_desgravamen['TASA']= pd.to_numeric(df_desgravamen['TASA'], errors='coerce')
df_desgravamen['PRIMABRUTACAN']= pd.to_numeric(df_desgravamen['PRIMABRUTACAN'], errors='coerce')
df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
df_desgravamen['ORIGEN ERROR'] = df_desgravamen['ORIGEN ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
#df_desgravamen['CODIGO ERROR'] = df_desgravamen['CODIGO ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
df_desgravamen['DESCRIPCION ERROR'] = df_desgravamen['DESCRIPCION ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 13
#      11 df_desgravamen['PRIMANETACAN']= pd.to_numeric(df_desgravamen['PRIMANETACAN'], errors='coerce')
#      12 df_desgravamen['ORIGEN ERROR'] = df_desgravamen['ORIGEN ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
# ---> 13 df_desgravamen['CODIGO ERROR'] = df_desgravamen['CODIGO ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
#      14 df_desgravamen['DESCRIPCION ERROR'] = df_desgravamen['DESCRIPCION ERROR'].apply(lambda x: str(int(x)) if pd.notnull(x) else '0')
#
# File c:\Users\Nelvin Velazco\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
# ...

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO PRODUCTO          48852 non-null  float64
#  1   COD DE CERTIFICADO       50659 non-null  object
#  2   FECINI_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  3   FECFIN_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  4   IDEDET                   50659 non-null  int64
#  5   TIPO MOVIMIENTO          50659 non-null  object
#  6   FEC. INICIO              50142 non-null  datetime64[ns]
#  7   FEC. FIN                 50142 non-null  datetime64[ns]
#  8   MONEDA                   50659 non-null  object
#  9   SUMA ASEGURADA           50146 non-null  float64
#  10  TASA                     50657 non-null  float64
#  11  PRIMABRUTACAN            50151 non-null  float64
#  12  PRIMANETACAN             50659 non-null  float64
# ...

# %%
df_desgravamen.head(5)
# Out:
#    CODIGO PRODUCTO  COD DE CERTIFICADO FECINI_ALTA_CERTIFICADO  \
# 0           3070.0  110291214000143008                     NaT
# 1           3070.0  110277104000246000                     NaT
# 2           3070.0  110354884000092000                     NaT
# 3           3070.0  110195594000396992                     NaT
# 4           3827.0  110960264000002000                     NaT
#
#   FECFIN_ALTA_CERTIFICADO     IDEDET TIPO MOVIMIENTO FEC. INICIO   FEC. FIN  \
# 0                     NaT   76792662      Renovacion  2015-03-26 2015-04-26
# 1                     NaT   76792295      Renovacion  2015-03-20 2015-04-20
# 2                     NaT   76795338      Renovacion  2015-03-12 2015-04-12
# 3                     NaT   76787274      Renovacion  2015-03-18 2015-04-18
# 4                     NaT  142143999      Renovacion  2016-06-06 2016-07-06
#
#   MONEDA  SUMA ASEGURADA  TASA  PRIMABRUTACAN  PRIMANETACAN  \
# 0    SOL             0.0   0.0           1.53          1.49
# ...

# %%
df_desgravamen= df_desgravamen.fillna({'CODIGO PRODUCTO':0, 'SUMA ASEGURADA':0, 'TASA':0, 'PRIMABRUTACAN':0, 'PRIMANETACAN':0})

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50659 entries, 0 to 50658
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO PRODUCTO          50659 non-null  float64
#  1   COD DE CERTIFICADO       50659 non-null  object
#  2   FECINI_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  3   FECFIN_ALTA_CERTIFICADO  33562 non-null  datetime64[ns]
#  4   IDEDET                   50659 non-null  int64
#  5   TIPO MOVIMIENTO          50659 non-null  object
#  6   FEC. INICIO              50142 non-null  datetime64[ns]
#  7   FEC. FIN                 50142 non-null  datetime64[ns]
#  8   MONEDA                   50659 non-null  object
#  9   SUMA ASEGURADA           50659 non-null  float64
#  10  TASA                     50659 non-null  float64
#  11  PRIMABRUTACAN            50659 non-null  float64
#  12  PRIMANETACAN             50659 non-null  float64
# ...

# %%
df_errores.head()
# Out:
#   CODIGO_ERROR                                  DESCRIPCION_ERROR  \
# 0         1068  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...
# 1         0003                            ERROR EN CARGA DE TRAMA
# 2         1155                         TRAMA REPETIDA O DUPLICADA
# 3         1150                                      ERROR EN ALTA
# 4         1152                                      ERROR EN ALTA
#
#                                              DETALLE           SOLUCION  \
# 0  YA EXISTE UN PAGO CON LA MISMA FECHA DE INICIO...  CONFIGURACION SAS
# 1                            ERROR EN CARGA DE TRAMA    ANALISIS EMISOR
# 2                         TRAMA REPETIDA O DUPLICADA  CONFIGURACION SAS
# 3  EL ALTA DEL NRO. CERTIFICADO EXTERNO SE ENCUEN...    ANALISIS EMISOR
# 4  NO EXISTE ALTA PARA EL CERTIFICADO O TIENE BAJ...    ANALISIS EMISOR
#
#        SOLUCION 2
# 0  ANULAR MASIVAS
# 1             NaN
# 2  ANULAR MASIVAS
# 3             NaN
# 4             NaN

# %% [markdown]
# ---

# %%
df_desgravamen[df_desgravamen['FECINI_ALTA_CERTIFICADO'].isnull()]['FECINI_ALTA_CERTIFICADO'].isnull().value_counts()
# Out:
# FECINI_ALTA_CERTIFICADO
# True    17097
# Name: count, dtype: int64

# %%
#TIPO MOVIMIENTO
df_desgravamen['FECINI_ALTA_CERTIFICADO'].value_counts()  # Counting occurrences of each unique value in the 'TIPO MOVIMIENTO' column
# Out:
# FECINI_ALTA_CERTIFICADO
# 2015-03-31    134
# 2014-12-30    124
# 2015-05-29    114
# 2015-10-30    106
# 2015-07-31    105
#              ...
# 2012-08-23      1
# 2013-01-08      1
# 2013-05-08      1
# 2013-03-11      1
# 2017-01-15      1
# Name: count, Length: 1161, dtype: int64

# %%
#MONEDA
df_desgravamen['MONEDA'].value_counts()  # Counting occurrences of each unique value in the 'MONEDA' column
# Out:
# MONEDA
# SOL    46356
# USD     4302
# Name: count, dtype: int64

# %%
df_desgravamen[df_desgravamen['SUMA ASEGURADA'].isnull()]['SUMA ASEGURADA'].isnull().value_counts()
# Out:
# SUMA ASEGURADA
# True    513
# Name: count, dtype: int64
